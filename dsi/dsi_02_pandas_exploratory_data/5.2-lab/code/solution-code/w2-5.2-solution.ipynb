# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Read in billboard.csv as a data frame

dfBB = pd.read_csv('billboard.csv')
dfBB
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
# The simplest pivot table must have a dataframe and an 
# index. Let’s use the artist as our index.

dfArtist = pd.pivot_table(df,index=["artist.inverted"])
dfArtist
# Out:
#                       x11th.week  x12th.week  x17th.week  x18th.week  \
# artist.inverted
# 2 Pac                        NaN         NaN         NaN         NaN
# 2Ge+her                      NaN         NaN         NaN         NaN
# 3 Doors Down           56.000000   55.000000   48.500000        42.5
# 504 Boyz               64.000000   70.000000   92.000000        96.0
# 98�                     7.000000   22.000000   66.000000        84.0
# A*Teens                      NaN         NaN         NaN         NaN
# Aaliyah                23.000000   22.500000   32.000000        34.5
# Adams, Yolanda         66.000000   68.000000   67.000000        71.0
# Adkins, Trace          92.000000         NaN         NaN         NaN
# Aguilera, Christina     6.666667    2.333333   16.666667        22.0
# Alice Deejay           36.000000   37.000000   65.000000        68.0
# Allan, Gary                  NaN         NaN         NaN         NaN
# ...

# %%
# Let's look at the data by artist and track. 

dfArtistTrack = pd.pivot_table(df,index=["artist.inverted","track"])
dfArtistTrack
# Out:
#                                                                          x11th.week  \
# artist.inverted      track
# 2 Pac                Baby Don't Cry (Keep Ya Head Up II)                        NaN
# 2Ge+her              The Hardest Part Of Breaking Up (Is Getting Bac...         NaN
# 3 Doors Down         Kryptonite                                                  51
#                      Loser                                                       61
# 504 Boyz             Wobble Wobble                                               64
# 98�                  Give Me Just One Night (Una Noche)                           7
# A*Teens              Dancing Queen                                              NaN
# Aaliyah              I Don't Wanna                                               37
#                      Try Again                                                    9
# Adams, Yolanda       Open My Heart                                               66
# ...

# %%
# find out the number of weeks each song has been on the billboard

dfWeeksOnBillboard = df.isnull().sum(axis=1)
dfWeeksOnBillboard

# %%
# add this as a new column

dfArtistTrackWeeks = pd.concat([dfWeeksOnBillboard, dfBB], axis=1)
dfArtistTrackWeeks
# Out:
#       0  year      artist.inverted  \
# 0    48  2000      Destiny's Child
# 1    50  2000              Santana
# 2    43  2000        Savage Garden
# 3    52  2000              Madonna
# 4    55  2000  Aguilera, Christina
# 5    52  2000                Janet
# 6    44  2000      Destiny's Child
# 7    56  2000    Iglesias, Enrique
# 8    50  2000                Sisqo
# 9    21  2000             Lonestar
# 10   51  2000               N'Sync
# 11   52  2000  Aguilera, Christina
# 12   35  2000     Vertical Horizon
# 13   29  2000                Creed
# 14   44  2000              Aaliyah
# 15   37  2000      matchbox twenty
# 16   56  2000        Carey, Mariah
# 17   23  2000          Hill, Faith
# 18   46  2000                  Mya
# 19   48  2000                Dream
# 20   39  2000        Braxton, Toni
# 21   44  2000        Anthony, Marc
# 22   56  2000                  98�
# 23   44  2000      Destiny's Child
# 24   23  2000         3 Doors Down
# ...

# %%
dfArtistTrackWeeks = dfArtistTrackWeeks.iloc[:,[0,2,3]]
dfArtistTrackWeeks
# Out:
#       0      artist.inverted  \
# 0    48      Destiny's Child
# 1    50              Santana
# 2    43        Savage Garden
# 3    52              Madonna
# 4    55  Aguilera, Christina
# 5    52                Janet
# 6    44      Destiny's Child
# 7    56    Iglesias, Enrique
# 8    50                Sisqo
# 9    21             Lonestar
# 10   51               N'Sync
# 11   52  Aguilera, Christina
# 12   35     Vertical Horizon
# 13   29                Creed
# 14   44              Aaliyah
# 15   37      matchbox twenty
# 16   56        Carey, Mariah
# 17   23          Hill, Faith
# 18   46                  Mya
# 19   48                Dream
# 20   39        Braxton, Toni
# 21   44        Anthony, Marc
# 22   56                  98�
# 23   44      Destiny's Child
# 24   23         3 Doors Down
# 25   48                Sisqo
# 26   54  Aguilera, Christina
# 27   48     Houston, Whitney
# 28   32                  Joe
# 29   44      Jordan, Montell
# ..   ..                  ...
# ...
