# %% [markdown]
# <img src="" style="float: left; margin: 10px;">
#
# # API Review with Foursquare API
# Week 8 | 3.1

# %% [markdown]
# ### LEARNING OBJECTIVES
# *After this lesson, you will be able to:*
#
# - Describe HTTPS and define an API
# - Introduce the Foursquare API
# - Discuss Foursquare API Functions
# - Receive and iterate through data from the Foursquare API
# - Describe how JSON stores data

# %% [markdown]
# ### STUDENT PRE-WORK
# *Before this lesson, students will need to be able to:*
#
# - Review API environment and access
# - Use python data structures
# - Simple Exploratory Data Analysis

# %% [markdown]
# ### LESSON GUIDE
# | Timing | Type | Topic |
# | --- | --- | --- |
# | 5 min | [Opening](#opening) | A Brief Review of APIs |
# | 10 min | [Introduction](#introduction) | Introduction to the Foursquare API and Python |
# | 15 min | [Demo](#demo) | Looking through datatypes in Foursquare |
# | 25 min | [Guided Practice](#Guided)  | Summarizing Foursquare data in Python |
# | 25 min | [Independent Practice](#Indy) | Data Analysis with Foursquare API |
# | 5 min |  [Conclusion](#conclusion)| Concluding Remarks |

# %% [markdown]
# #### (5 min) Opening:
# <a name = "opening"></a>
# ## (Re)Introducing APIs with Foursquare in mind
#
# As a review, an API call is just making HTTP requests to a server and sending/receiving structured data from that endpoint. We are still communicating with URLs, however instead of receiving markup, like we do with HTML pages, we receive data. If that data is structured as JSON, we can easily start reacting and communicating with it thanks to the provided JSON methods.

# %% [markdown]
# ## How do clients relate to servers?
# Where does the webapp live?

# %% [markdown]
# ### APIs: A Quick Review (10 min):
#
# Because our pages will be fully or partially rendered on the client side after we receive this data, there are a few best scenarios we need to take into account:
#
#   - Certain APIs require authentication, and we need to provide an API key either as a request parameter, in the header, or in the body of the call.
#   - When we make an API call after a user action, we need to give the user feedback that something is happening.
#   - We update our view(s) only after we get a return from the server.
#   - We need to account for us not receiving data back due to different interruptions/causes:
#     - Server timeout
#     - Wrong authentication information
#     - User loses connection
#     - Request URL not found
# - [Representational state transfer (REST)](https://en.wikipedia.org/wiki/Representational_state_transfer) is the most common architecture style for passing information to and from these API endpoints.
#
# ---
#
# As many of you probably know, Foursquare is a quasi-Geo-spatial social network, geared towards surfacing recommendations, location, and coordinated meetups. The end-user accomplishes this through a combination of texting, geo-tagging, and light content creation in the form of recommendations/reviews/etc. Often times the service is accessed via a mobile device, although one can engage in Foursquare activity through a desktop/laptop as well.
#
# The end user activity is incentivized/rewarded through accumulation of badges, titles (A sort of Gamification), and through getting (what's hoped) activity appropriate/contextualized coupons/discounts/sometimes free goods that are machine determined (i.e. some matching procedure/algorithm produced). Also, there is an intrinsic element to the incentive, like Facebook, many foursquare power-users end up using the service because their immediate friends/social network also utilize the service (the so-called "Network effect").
#
#
# ---

# %% [markdown]
# ## (5 mins) With the person next to you, open the REST link above and in your own words, come up with a description of REST.
#
# We will share.

# %% [markdown]
# <a name = "demo"></a>
# ## Demo: Accessing the Foursquare API (15 mins)
#
# Accessing the Foursquare API has become much simpler in recent years through the construction of 3rd party Python libraries that make the Oauth an data pull process much simpler, and wraps the data/meta-data in appropriate Python data-types.
#
# We will use 'foursquare' in Python, which can be loaded up in your system via easy_install or pip in the usual way (i.e. `pip install foursquare`).

# %% [markdown]
# #### Foursquare API OAuth process
#
# **Brief Review:** "OAuth" is a web protocol for authentication with a third-party service, like when you try to sign up for a website and get directed to sign in with Facebook. Essentially, the website is using Facebook to prove who you are
#
# To access the Foursquare API you must first register an App using the [foursquare App registration service](https://foursquare.com/developers/apps)
#
# Setup your new "App"
# <img src="https://snag.gy/BaSnZG.jpg">
# <img src="https://snag.gy/xCp2jU.jpg">
# <img src="https://snag.gy/d5Q1hT.jpg">
#
# This will give you the credentials you need to pull/use Foursquare data.

# %%
# !pip install foursquare
# Out:
# Collecting foursquare
#   Downloading foursquare-1%212015.5.26.tar.gz
# Requirement already satisfied (use --upgrade to upgrade): requests>=2.1 in /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages (from foursquare)
# Requirement already satisfied (use --upgrade to upgrade): six in /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages (from foursquare)
# Building wheels for collected packages: foursquare
# done
#   Stored in directory: /Users/davidyerrington/Library/Caches/pip/wheels/32/46/00/46578309875e33a4b55e5cc28c717ef125ff7efcf904efbbf0
# Successfully built foursquare
# Installing collected packages: foursquare
# Successfully installed foursquare-1!2015.5.26

# %%
import foursquare
import pandas as pd

CLIENT_ID = 'BZ2IGP3UJ5LWKZG5JZBLCNFP30GC5M35A5EWVA5PNJLFI5H1'   # Input your client id/ client secret here
CLIENT_SECRET = '0XUU2DT0TSFXIZIBC3VD2AM4SXXLWILYGIDV3NA22ECT2D1P'
client = foursquare.Foursquare(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)

# %% [markdown]
# ## Collecting Coordinate Bounds
#
# We're going to do a fun exercise that looks at our local venues and do simple counts. The first thing we need to do is construct a bounding box around our geo-area. A simple tool for this is here: http://boundingbox.klokantech.com/. Select your home location, and create a bounding box around it. Make sure your output coordinates is set to "raw CSV". Get that data and input it into a python list

# %%
# Example
# bounding_box = [x,y,z,t]  - Input the raw CSV file in here
x,y,z,t = (-122.4912071228,37.6730872297,-122.4623680115,37.6915634956)

# %% [markdown]
# ## Foursquare Data and Methods Overview (15 min)
#
# > Note: Break timing for this into two section at 15min + 10 min each, respectively
#
# Before we delve deeper into Python procedures, we need to understand the Foursquare data so we can better build a container to house the JSON data into a common tabular format.

# %%
search = client.venues.search(params={'ll': "%.2f, %.2f" % (y, x)})  # Put in a lat/long you're interested in
search
# Out:
# {u'confident': True,
#  u'venues': [{u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#       u'suffix': u'.png'},
#      u'id': u'50aa9e094b90af0d42d5de0d',
#      u'name': u'City',
#      u'pluralName': u'Cities',
#      u'primary': True,
#      u'shortName': u'City'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4c831e31dc018cfaf16ad66c',
#    u'location': {u'cc': u'US',
#     u'country': u'United States',
#     u'distance': 1265,
#     u'formattedAddress': [u'California', u'United States'],
#     u'lat': 37.671456749994746,
#     u'lng': -122.47575759887695,
#     u'state': u'California'},
#    u'name': u'City of Daly City',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 20677, u'tipCount': 24, u'usersCount': 2951},
#    u'url': u'http://www.dalycity.org',
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d1cb941735',
#      u'name': u'Food Truck',
#      u'pluralName': u'Food Trucks',
#      u'primary': True,
#      u'shortName': u'Food Truck'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'5344bafe498e2c48d8ffdb4d',
#    u'location': {u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1864,
#     u'formattedAddress': [u'Daly City, CA', u'United States'],
#     u'lat': 37.67363426707375,
#     u'lng': -122.46933835038679,
#     u'state': u'CA'},
#    u'name': u'KoJa Kitchen',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 15, u'tipCount': 0, u'usersCount': 15},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d1cb941735',
#      u'name': u'Food Truck',
#      u'pluralName': u'Food Trucks',
#      u'primary': True,
#      u'shortName': u'Food Truck'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'5716dd89498ee529a739aa4e',
#    u'location': {u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1802,
#     u'formattedAddress': [u'Daly City, CA', u'United States'],
#     u'lat': 37.67359006089644,
#     u'lng': -122.47005698169203,
#     u'state': u'CA'},
#    u'name': u'Off the Grid: Serramonte',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 8, u'tipCount': 0, u'usersCount': 7},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/apparel_kids_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d105951735',
#      u'name': u'Kids Store',
#      u'pluralName': u'Kids Stores',
#      u'primary': True,
#      u'shortName': u'Kids Store'}],
#    u'contact': {u'formattedPhone': u'(650) 755-8617',
#     u'phone': u'6507558617',
#     u'twitter': u'crazy8'},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4e5838acb61c5534c28d1721',
#    u'location': {u'address': u'31 Serramonte Ctr',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1777,
#     u'formattedAddress': [u'31 Serramonte Ctr',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.672133249606034,
#     u'lng': -122.47000723045316,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Crazy 8',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 153, u'tipCount': 1, u'usersCount': 72},
#    u'storeId': u'6000',
#    u'url': u'http://www.crazy8.com',
#    u'venueChains': [{u'id': u'556ca508a7c87f63786abbd0'}],
#    u'verified': True},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#       u'suffix': u'.png'},
#      u'id': u'4d954afda243a5684865b473',
#      u'name': u'Optical Shop',
#      u'pluralName': u'Optical Shops',
#      u'primary': True,
#      u'shortName': u'Optical'}],
#    u'contact': {u'facebook': u'334428099915658',
#     u'facebookName': u'Target Optical',
#     u'formattedPhone': u'(650) 756-6684',
#     u'phone': u'6507566684'},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4dc0a65c6a234f00553b41fc',
#    u'location': {u'address': u'133 Serramonte Ctr',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1689,
#     u'formattedAddress': [u'133 Serramonte Ctr',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.670495,
#     u'lng': -122.470837,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Target Optical',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 69, u'tipCount': 0, u'usersCount': 32},
#    u'url': u'http://local.targetoptical.com/ca/daly-city/133-serramonte-center.html?cid=yext_4962',
#    u'venueChains': [],
#    u'verified': False},
#   {u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d132941735',
#      u'name': u'Church',
#      u'pluralName': u'Churches',
#      u'primary': True,
#      u'shortName': u'Church'}],
#    u'contact': {u'formattedPhone': u'(650) 550-0071', u'phone': u'6505500071'},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4aad29b2f964a520cf5e20e3',
#    u'location': {u'address': u'50 Northridge Dr',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1216,
#     u'formattedAddress': [u'50 Northridge Dr',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.68065320561142,
#     u'lng': -122.49306857585907,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'KCPC - Korean Central Presbyterian Church',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 232, u'tipCount': 1, u'usersCount': 55},
#    u'venueChains': [],
#    u'verified': False},
#   {u'categories': [],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4efd842ef790570bcfe6ef90',
#    u'location': {u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1477,
#     u'formattedAddress': [u'Daly City, CA 94015', u'United States'],
#     u'lat': 37.683166,
#     u'lng': -122.487846,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'the hutski!',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 7, u'tipCount': 0, u'usersCount': 4},
#    u'venueChains': [],
#    u'verified': False},
#   {u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d171941735',
#      u'name': u'Event Space',
#      u'pluralName': u'Event Spaces',
#      u'primary': True,
#      u'shortName': u'Event Space'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4c4ba6ac46240f47b1c69af3',
#    u'location': {u'address': u'33 Belhaven Ct',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1109,
#     u'formattedAddress': [u'33 Belhaven Ct',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.67327899552767,
#     u'lng': -122.4781135975627,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Traditions Belhaven Clubhouse',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 92, u'tipCount': 0, u'usersCount': 9},
#    u'venueChains': [],
#    u'verified': False},
#   {u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d177941735',
#      u'name': u"Doctor's Office",
#      u'pluralName': u"Doctor's Offices",
#      u'primary': True,
#      u'shortName': u"Doctor's Office"}],
#    u'contact': {u'formattedPhone': u'(650) 994-3000', u'phone': u'6509943000'},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4c6c169d463537043b6605bc',
#    u'location': {u'address': u'901 Campus Dr Ste 210',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'crossStreet': u'Hickey Blvd',
#     u'distance': 1363,
#     u'formattedAddress': [u'901 Campus Dr Ste 210 (Hickey Blvd)',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.665293,
#     u'lng': -122.475709,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'PediaHealth Medical Group',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 50, u'tipCount': 6, u'usersCount': 12},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d14a941735',
#      u'name': u'Vietnamese Restaurant',
#      u'pluralName': u'Vietnamese Restaurants',
#      u'primary': True,
#      u'shortName': u'Vietnamese'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'5619860d498eb2f452c121e2',
#    u'location': {u'address': u'188 Skyline Plz',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1307,
#     u'formattedAddress': [u'188 Skyline Plz',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.68161460423057,
#     u'lng': -122.48777244402142,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Pho Huynh Hiep 4',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 166, u'tipCount': 1, u'usersCount': 106},
#    u'url': u'http://www.kevinnoodlehouse.com',
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d186941735',
#      u'name': u'Liquor Store',
#      u'pluralName': u'Liquor Stores',
#      u'primary': True,
#      u'shortName': u'Liquor Store'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4c0c23d5340720a13c3c8993',
#    u'location': {u'address': u'242 Skyline Plz',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1336,
#     u'formattedAddress': [u'242 Skyline Plz',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.68190988109722,
#     u'lng': -122.48805284500122,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Jug Shop Liquors',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 161, u'tipCount': 0, u'usersCount': 67},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d113951735',
#      u'name': u'Gas Station',
#      u'pluralName': u'Gas Stations',
#      u'primary': True,
#      u'shortName': u'Gas Station'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'53f02f75498e358e3e769924',
#    u'location': {u'cc': u'US',
#     u'city': u'Daly',
#     u'country': u'United States',
#     u'distance': 1427,
#     u'formattedAddress': [u'Daly, CA', u'United States'],
#     u'lat': 37.68277340308603,
#     u'lng': -122.48860148718337,
#     u'state': u'CA'},
#    u'name': u'Quality Fuel',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 2, u'tipCount': 0, u'usersCount': 2},
#    u'venueChains': [],
#    u'verified': False},
#   {u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#       u'suffix': u'.png'},
#      u'id': u'4d954b06a243a5684965b473',
#      u'name': u'Residential Building (Apartment / Condo)',
#      u'pluralName': u'Residential Buildings (Apartments / Condos)',
#      u'primary': True,
#      u'shortName': u'Residential'}],
#    u'contact': {u'formattedPhone': u'(650) 557-4117', u'phone': u'6505574117'},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4c7d22cd486a9521ef8fa199',
#    u'location': {u'address': u'670 Hickey Blvd',
#     u'cc': u'US',
#     u'city': u'Pacifica',
#     u'country': u'United States',
#     u'crossStreet': u'Gateway Dr',
#     u'distance': 1615,
#     u'formattedAddress': [u'670 Hickey Blvd (Gateway Dr)',
#      u'Pacifica, CA 94044',
#      u'United States'],
#     u'lat': 37.65894273933113,
#     u'lng': -122.47813295208623,
#     u'postalCode': u'94044',
#     u'state': u'CA'},
#    u'name': u'Pacifica Park Apartments',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 72, u'tipCount': 1, u'usersCount': 25},
#    u'storeId': u'',
#    u'venueChains': [{u'id': u'556a34b9a7c8957d73d4de04'}],
#    u'verified': True},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#       u'suffix': u'.png'},
#      u'id': u'522e32fae4b09b556e370f19',
#      u'name': u'Eye Doctor',
#      u'pluralName': u'Eye Doctors',
#      u'primary': True,
#      u'shortName': u'Eye Doctor'}],
#    u'contact': {u'formattedPhone': u'(650) 756-2020', u'phone': u'6507562020'},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'50f75cbbe4b02622005cbe6d',
#    u'location': {u'address': u'901 Campus Dr Ste 205',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'crossStreet': u'Hickey Blvd.',
#     u'distance': 1352,
#     u'formattedAddress': [u'901 Campus Dr Ste 205 (Hickey Blvd.)',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.66524135602815,
#     u'lng': -122.47587218551746,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Peninsula Opthamology Group',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 32, u'tipCount': 1, u'usersCount': 5},
#    u'venueChains': [],
#    u'verified': False},
#   {u'categories': [],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4ccdc39aba0a548153534559',
#    u'location': {u'address': u'39 Saint Francis Sq',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'crossStreet': u'Southgate Avenue',
#     u'distance': 1094,
#     u'formattedAddress': [u'39 Saint Francis Sq (Southgate Avenue)',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.674394984381,
#     u'lng': -122.47889041900635,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'RCBC Remit',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 17, u'tipCount': 0, u'usersCount': 7},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d186941735',
#      u'name': u'Liquor Store',
#      u'pluralName': u'Liquor Stores',
#      u'primary': True,
#      u'shortName': u'Liquor Store'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4ce8c5e3f3bda1431427bce4',
#    u'location': {u'address': u'7 Saint Francis Sq',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'crossStreet': u'Southgate & St Francis',
#     u'distance': 1121,
#     u'formattedAddress': [u'7 Saint Francis Sq (Southgate & St Francis)',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.674879,
#     u'lng': -122.478869,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'St. Francis Square Discount Liquors',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 209, u'tipCount': 1, u'usersCount': 91},
#    u'venueChains': [],
#    u'verified': False},
#   {u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#       u'suffix': u'.png'},
#      u'id': u'4f2a25ac4b909258e854f55f',
#      u'name': u'Neighborhood',
#      u'pluralName': u'Neighborhoods',
#      u'primary': True,
#      u'shortName': u'Neighborhood'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4be756922457a5934ee0ad15',
#    u'location': {u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1276,
#     u'formattedAddress': [u'Daly City, CA 94015', u'United States'],
#     u'lat': 37.673291215412576,
#     u'lng': -122.47612645510452,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Little Philippines',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 1376, u'tipCount': 0, u'usersCount': 37},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d12f951735',
#      u'name': u'Resort',
#      u'pluralName': u'Resorts',
#      u'primary': True,
#      u'shortName': u'Resort'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4fd8d6b2e4b0bb2199d93ae8',
#    u'location': {u'address': u'El Dorado Dr',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'crossStreet': u'San Fernando Way',
#     u'distance': 1549,
#     u'formattedAddress': [u'El Dorado Dr (San Fernando Way)',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.68033237569879,
#     u'lng': -122.4782103368727,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Rainbow 314',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 720, u'tipCount': 2, u'usersCount': 6},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d151941735',
#      u'name': u'Taco Place',
#      u'pluralName': u'Taco Places',
#      u'primary': True,
#      u'shortName': u'Tacos'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'522f72b511d219f2ae04446b',
#    u'location': {u'address': u'713 Hickey Blvd',
#     u'cc': u'US',
#     u'city': u'Pacifica',
#     u'country': u'United States',
#     u'crossStreet': u'Skyline Blvd',
#     u'distance': 1436,
#     u'formattedAddress': [u'713 Hickey Blvd (Skyline Blvd)',
#      u'Pacifica, CA 94044',
#      u'United States'],
#     u'lat': 37.660798,
#     u'lng': -122.478573,
#     u'postalCode': u'94044',
#     u'state': u'CA'},
#    u'name': u"Guerrero's Taqueria #2",
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 242, u'tipCount': 1, u'usersCount': 103},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d112941735',
#      u'name': u'Juice Bar',
#      u'pluralName': u'Juice Bars',
#      u'primary': True,
#      u'shortName': u'Juice Bar'}],
#    u'contact': {u'formattedPhone': u'(650) 997-4559',
#     u'phone': u'6509974559',
#     u'twitter': u'surfcitysqueeze'},
#    u'hasMenu': True,
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4dd3157252b1f20e6808817f',
#    u'location': {u'address': u'106M Serramonte Ctr',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1690,
#     u'formattedAddress': [u'106M Serramonte Ctr',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.67199,
#     u'lng': -122.470983,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'menu': {u'anchor': u'View Menu',
#     u'label': u'Menu',
#     u'mobileUrl': u'https://foursquare.com/v/4dd3157252b1f20e6808817f/device_menu',
#     u'type': u'Menu',
#     u'url': u'https://foursquare.com/v/surf-city-squeeze/4dd3157252b1f20e6808817f/menu'},
#    u'name': u'Surf City Squeeze',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 171, u'tipCount': 5, u'usersCount': 115},
#    u'url': u'http://www.surfcitysqueeze.com',
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       u'suffix': u'.png'},
#      u'id': u'52f2ab2ebcbc57f1066b8b27',
#      u'name': u'Mattress Store',
#      u'pluralName': u'Mattress Stores',
#      u'primary': True,
#      u'shortName': u'Mattress Store'}],
#    u'contact': {u'facebook': u'163855856966161',
#     u'facebookName': u'Sleep Number',
#     u'facebookUsername': u'SleepNumberDalyCityCA',
#     u'formattedPhone': u'(415) 508-4680',
#     u'phone': u'4155084680',
#     u'twitter': u'sleepnumber'},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4d6989cab6f46dcbf40424b2',
#    u'location': {u'address': u'102 Serramonte Center',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1658,
#     u'formattedAddress': [u'102 Serramonte Center',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.671761,
#     u'lng': -122.47131,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Sleep Number',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 34, u'tipCount': 0, u'usersCount': 26},
#    u'storeId': u'',
#    u'url': u'http://stores.sleepnumber.com/ca/daly-city/102-serramonte-center.html',
#    u'venueChains': [{u'id': u'556ce747aceaff43eb0568a1'}],
#    u'verified': True},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/apparel_lingerie_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d109951735',
#      u'name': u'Lingerie Store',
#      u'pluralName': u'Lingerie Stores',
#      u'primary': True,
#      u'shortName': u'Lingerie'}],
#    u'contact': {u'formattedPhone': u'(650) 757-1428',
#     u'phone': u'6507571428',
#     u'twitter': u'victoriassecret'},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'50605ce23d7c47f05ba4137e',
#    u'location': {u'address': u'121 Serramonte Ctr',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1716,
#     u'formattedAddress': [u'121 Serramonte Ctr',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.67136878560091,
#     u'lng': -122.47059318798527,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u"Victoria's Secret",
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 168, u'tipCount': 0, u'usersCount': 123},
#    u'storeId': u'164',
#    u'url': u'http://www.victoriassecret.com',
#    u'venueChains': [{u'id': u'556de729a7c82f0fe9875f3c'}],
#    u'verified': True},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/laundry_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d1fc941735',
#      u'name': u'Laundry Service',
#      u'pluralName': u'Laundry Services',
#      u'primary': True,
#      u'shortName': u'Laundry'}],
#    u'contact': {u'formattedPhone': u'(650) 922-9229', u'phone': u'6509229229'},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4d6a636b9bd6a14327936cdf',
#    u'location': {u'address': u'51 Saint Francis Sq',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1084,
#     u'formattedAddress': [u'51 Saint Francis Sq',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.674701041458675,
#     u'lng': -122.4792218613077,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Tidy Cleaners',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 64, u'tipCount': 2, u'usersCount': 14},
#    u'venueChains': [],
#    u'verified': False},
#   {u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/baseballfield_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d1e8941735',
#      u'name': u'Baseball Field',
#      u'pluralName': u'Baseball Fields',
#      u'primary': True,
#      u'shortName': u'Baseball Field'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4fd15cb1e4b07b1232bd4803',
#    u'location': {u'cc': u'US',
#     u'city': u'Pacifica',
#     u'country': u'United States',
#     u'distance': 1267,
#     u'formattedAddress': [u'Pacifica, CA 94044', u'United States'],
#     u'lat': 37.66060496277349,
#     u'lng': -122.48187499359423,
#     u'postalCode': u'94044',
#     u'state': u'CA'},
#    u'name': u'Fairmont Baseball Field',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 27, u'tipCount': 1, u'usersCount': 18},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d14f941735',
#      u'name': u'Southern / Soul Food Restaurant',
#      u'pluralName': u'Southern / Soul Food Restaurants',
#      u'primary': True,
#      u'shortName': u'Southern / Soul'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'56116cb7498eee56f592b580',
#    u'location': {u'address': u'3 Serramonte Ctr Ste 59A',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1818,
#     u'formattedAddress': [u'3 Serramonte Ctr Ste 59A',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.672588248621416,
#     u'lng': -122.46962027556478,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Home of Chicken and Waffles',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 137, u'tipCount': 0, u'usersCount': 116},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d108951735',
#      u'name': u"Women's Store",
#      u'pluralName': u"Women's Stores",
#      u'primary': True,
#      u'shortName': u"Women's Store"}],
#    u'contact': {u'formattedPhone': u'(650) 756-2863',
#     u'phone': u'6507562863',
#     u'twitter': u'charlotterusse'},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'549b4c97498e3242ba109459',
#    u'location': {u'address': u'3 Serramonte Ctr',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1697,
#     u'formattedAddress': [u'3 Serramonte Ctr',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.672641,
#     u'lng': -122.471025,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Charlotte Russe',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 26, u'tipCount': 0, u'usersCount': 9},
#    u'storeId': u'760',
#    u'url': u'https://www.facebook.com/CharlotteRusse',
#    u'venueChains': [{u'id': u'556cfc3faceaff43eb0690bd'}],
#    u'verified': True},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d142941735',
#      u'name': u'Asian Restaurant',
#      u'pluralName': u'Asian Restaurants',
#      u'primary': True,
#      u'shortName': u'Asian'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'56e0e4fe498e92e6823b7ec9',
#    u'location': {u'address': u'83 Skyline Plz',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1371,
#     u'formattedAddress': [u'83 Skyline Plz',
#      u'Daly City, CA 94015',
#      u'United States'],
#     u'lat': 37.682155,
#     u'lng': -122.487441,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'name': u'Fresh Elements',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 36, u'tipCount': 1, u'usersCount': 33},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d110951735',
#      u'name': u'Salon / Barbershop',
#      u'pluralName': u'Salons / Barbershops',
#      u'primary': True,
#      u'shortName': u'Salon / Barbershop'}],
#    u'contact': {},
#    u'hasMenu': True,
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4c67197ee1da1b8d1e179dc3',
#    u'location': {u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1076,
#     u'formattedAddress': [u'Daly City, CA 94015', u'United States'],
#     u'lat': 37.67450005,
#     u'lng': -122.47918701171875,
#     u'postalCode': u'94015',
#     u'state': u'CA'},
#    u'menu': {u'anchor': u'View Products',
#     u'label': u'Products',
#     u'mobileUrl': u'https://foursquare.com/v/4c67197ee1da1b8d1e179dc3/device_menu',
#     u'type': u'Products',
#     u'url': u'https://foursquare.com/v/elite-salon/4c67197ee1da1b8d1e179dc3/menu'},
#    u'name': u'Elite Salon',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 277, u'tipCount': 1, u'usersCount': 52},
#    u'venueChains': [],
#    u'verified': False},
#   {u'allowMenuUrlEdit': True,
#    u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#       u'suffix': u'.png'},
#      u'id': u'4bf58dd8d48988d106951735',
#      u'name': u"Men's Store",
#      u'pluralName': u"Men's Stores",
#      u'primary': True,
#      u'shortName': u"Men's Store"}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4bb7c8ec314e9521f0b3479d',
#    u'location': {u'address': u'Serramonte',
#     u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1669,
#     u'formattedAddress': [u'Serramonte', u'Daly City, CA', u'United States'],
#     u'lat': 37.67197723321072,
#     u'lng': -122.47121783720802,
#     u'state': u'CA'},
#    u'name': u'Hat Club',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 222, u'tipCount': 0, u'usersCount': 129},
#    u'venueChains': [],
#    u'verified': False},
#   {u'categories': [{u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#       u'suffix': u'.png'},
#      u'id': u'4f2a25ac4b909258e854f55f',
#      u'name': u'Neighborhood',
#      u'pluralName': u'Neighborhoods',
#      u'primary': True,
#      u'shortName': u'Neighborhood'}],
#    u'contact': {},
#    u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'},
#    u'id': u'4e57c3afaeb7eff130d01b9e',
#    u'location': {u'cc': u'US',
#     u'city': u'Daly City',
#     u'country': u'United States',
#     u'distance': 1277,
#     u'formattedAddress': [u'Daly City, CA', u'United States'],
#     u'lat': 37.673291215412576,
#     u'lng': -122.47611539991796,
#     u'state': u'CA'},
#    u'name': u'Traditions Belhaven',
#    u'referralId': u'v-1464758357',
#    u'specials': {u'count': 0, u'items': []},
#    u'stats': {u'checkinsCount': 1497, u'tipCount': 0, u'usersCount': 4},
#    u'venueChains': [],
#    u'verified': False}]}

# %% [markdown]
# Observe that the data is housed in a nested hierarchy, we can access the data using the bracket notation in Python Pandas.
#
# ```python
#     u'stats': {u'checkinsCount': 7197, u'tipCount': 15, u'usersCount': 2266}
# ```
#
# Can be accessed as
# ```python
#     data_frame['stats']['checkingCount']
# ```

# %% [markdown]
# #### Foursquare API Data Types (10 min)
#
# Below is a useful table for data types that can be accessed in Foursquare. In general, Foursquare Data for the users require explicit permission. However, Venues data can be used for exploratory analysis with a user-less credential.
#
# <table width="600px"><tbody><tr><th></th><th>General</th><th>Aspects</th><th>Actions</th></tr><tr><th>
# <a href="https://developer.foursquare.com/docs/users/users" class="auth noVenuesReq">users</a></th><td>
# <a href="https://developer.foursquare.com/docs/users/search" class="auth noVenuesReq">search</a><br><a href="https://developer.foursquare.com/docs/users/requests" class="auth noVenuesReq">requests</a></td><td>
# <a href="https://developer.foursquare.com/docs/users/venuehistory" class="auth noVenuesReq">venuehistory</a><br><a href="https://developer.foursquare.com/docs/users/photos" class="auth noVenuesReq">photos</a><br><a href="https://developer.foursquare.com/docs/users/tastes" class="auth noVenuesReq">tastes</a><br><a href="https://developer.foursquare.com/docs/users/friends" class="auth noVenuesReq">friends</a><br><a href="https://developer.foursquare.com/docs/users/checkins" class="auth noVenuesReq">checkins</a><br><a href="https://developer.foursquare.com/docs/users/tips" class="auth noVenuesReq">tips</a><br><a href="https://developer.foursquare.com/docs/users/venuelikes" class="auth noVenuesReq">venuelikes</a><br><a href="https://developer.foursquare.com/docs/users/mayorships" class="auth noVenuesReq">mayorships</a><br><a href="https://developer.foursquare.com/docs/users/lists" class="auth noVenuesReq">lists</a></td><td><a href="https://developer.foursquare.com/docs/users/deny" class="auth noVenuesReq">deny</a><br><a href="https://developer.foursquare.com/docs/users/setpings" class="auth noVenuesReq">setpings</a><br><a href="https://developer.foursquare.com/docs/users/update" class="auth noVenuesReq">update</a><br><a href="https://developer.foursquare.com/docs/users/unfriend" class="auth noVenuesReq">unfriend</a><br><a href="https://developer.foursquare.com/docs/users/approve" class="auth noVenuesReq">approve</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/venues/venues" class="noAuth noVenuesReq">venues</a></th><td><a href="https://developer.foursquare.com/docs/venues/search" class="noAuth noVenuesReq">search</a><br><a href="https://developer.foursquare.com/docs/venues/suggestcompletion" class="noAuth noVenuesReq">suggestcompletion</a><br><a href="https://developer.foursquare.com/docs/venues/categories" class="noAuth noVenuesReq">categories</a><br><a href="https://developer.foursquare.com/docs/venues/timeseries" class="auth venuesReq">timeseries</a><br><a href="https://developer.foursquare.com/docs/venues/trending" class="noAuth noVenuesReq">trending</a><br><a href="https://developer.foursquare.com/docs/venues/explore" class="noAuth noVenuesReq">explore</a><br><a href="https://developer.foursquare.com/docs/venues/add" class="auth noVenuesReq">add</a><br><a href="https://developer.foursquare.com/docs/venues/managed" class="auth venuesReq">managed</a></td><td><a href="https://developer.foursquare.com/docs/venues/similar" class="auth noVenuesReq">similar</a><br><a href="https://developer.foursquare.com/docs/venues/photos" class="noAuth noVenuesReq">photos</a><br><a href="https://developer.foursquare.com/docs/venues/events" class="noAuth noVenuesReq">events</a><br><a href="https://developer.foursquare.com/docs/venues/likes" class="noAuth noVenuesReq">likes</a><br><a href="https://developer.foursquare.com/docs/venues/nextvenues" class="noAuth noVenuesReq">nextvenues</a><br><a href="https://developer.foursquare.com/docs/venues/hours" class="noAuth noVenuesReq">hours</a><br><a href="https://developer.foursquare.com/docs/venues/stats" class="auth venuesReq">stats</a><br><a href="https://developer.foursquare.com/docs/venues/links" class="noAuth noVenuesReq">links</a><br><a href="https://developer.foursquare.com/docs/venues/menu" class="noAuth noVenuesReq">menu</a><br><a href="https://developer.foursquare.com/docs/venues/tips" class="noAuth noVenuesReq">tips</a><br><a href="https://developer.foursquare.com/docs/venues/herenow" class="auth noVenuesReq">herenow</a><br><a href="https://developer.foursquare.com/docs/venues/listed" class="noAuth noVenuesReq">listed</a></td><td><a href="https://developer.foursquare.com/docs/venues/claim" class="auth venuesReq">claim</a><br><a href="https://developer.foursquare.com/docs/venues/dislike" class="auth noVenuesReq">dislike</a><br><a href="https://developer.foursquare.com/docs/venues/flag" class="auth noVenuesReq">flag</a><br><a href="https://developer.foursquare.com/docs/venues/proposeedit" class="auth noVenuesReq">proposeedit</a><br><a href="https://developer.foursquare.com/docs/venues/like" class="auth noVenuesReq">like</a><br><a href="https://developer.foursquare.com/docs/venues/setrole" class="auth venuesReq">setrole</a><br><a href="https://developer.foursquare.com/docs/venues/edit" class="auth venuesReq">edit</a><br><a href="https://developer.foursquare.com/docs/venues/setsinglelocation" class="auth venuesReq">setsinglelocation</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/venuegroups/venuegroups" class="auth venuesReq">venuegroups</a></th><td><a href="https://developer.foursquare.com/docs/venuegroups/list" class="auth venuesReq">list</a><br><a href="https://developer.foursquare.com/docs/venuegroups/delete" class="auth venuesReq">delete</a><br><a href="https://developer.foursquare.com/docs/venuegroups/add" class="auth venuesReq">add</a></td><td><a href="https://developer.foursquare.com/docs/venuegroups/timeseries" class="auth venuesReq">timeseries</a></td><td><a href="https://developer.foursquare.com/docs/venuegroups/update" class="auth venuesReq">update</a><br><a href="https://developer.foursquare.com/docs/venuegroups/addvenue" class="auth venuesReq">addvenue</a><br><a href="https://developer.foursquare.com/docs/venuegroups/edit" class="auth venuesReq">edit</a><br><a href="https://developer.foursquare.com/docs/venuegroups/removevenue" class="auth venuesReq">removevenue</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/checkins/checkins" class="auth noVenuesReq">checkins</a></th><td><a href="https://developer.foursquare.com/docs/checkins/resolve" class="auth noVenuesReq">resolve</a><br><a href="https://developer.foursquare.com/docs/checkins/recent" class="auth noVenuesReq">recent</a><br><a href="https://developer.foursquare.com/docs/checkins/add" class="auth noVenuesReq">add</a></td><td><a href="https://developer.foursquare.com/docs/checkins/likes" class="noAuth noVenuesReq">likes</a></td><td><a href="https://developer.foursquare.com/docs/checkins/deletecomment" class="auth noVenuesReq">deletecomment</a><br><a href="https://developer.foursquare.com/docs/checkins/like" class="auth noVenuesReq">like</a><br><a href="https://developer.foursquare.com/docs/checkins/addpost" class="auth noVenuesReq">addpost</a><br><a href="https://developer.foursquare.com/docs/checkins/addcomment" class="auth noVenuesReq">addcomment</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/tips/tips" class="noAuth noVenuesReq">tips</a></th><td><a href="https://developer.foursquare.com/docs/tips/add" class="auth noVenuesReq">add</a></td><td><a href="https://developer.foursquare.com/docs/tips/likes" class="noAuth noVenuesReq">likes</a><br><a href="https://developer.foursquare.com/docs/tips/saves" class="noAuth noVenuesReq">saves</a><br><a href="https://developer.foursquare.com/docs/tips/listed" class="noAuth noVenuesReq">listed</a></td><td><a href="https://developer.foursquare.com/docs/tips/unmark" class="auth noVenuesReq">unmark</a><br><a href="https://developer.foursquare.com/docs/tips/flag" class="auth noVenuesReq">flag</a><br><a href="https://developer.foursquare.com/docs/tips/like" class="auth noVenuesReq">like</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/lists/lists" class="noAuth noVenuesReq">lists</a></th><td><a href="https://developer.foursquare.com/docs/lists/add" class="auth noVenuesReq">add</a></td><td><a href="https://developer.foursquare.com/docs/lists/followers" class="noAuth noVenuesReq">followers</a><br><a href="https://developer.foursquare.com/docs/lists/suggestphoto" class="auth noVenuesReq">suggestphoto</a><br><a href="https://developer.foursquare.com/docs/lists/suggesttip" class="auth noVenuesReq">suggesttip</a><br><a href="https://developer.foursquare.com/docs/lists/saves" class="noAuth noVenuesReq">saves</a><br><a href="https://developer.foursquare.com/docs/lists/items" class="auth noVenuesReq">items</a><br><a href="https://developer.foursquare.com/docs/lists/suggestvenues" class="auth noVenuesReq">suggestvenues</a></td><td><a href="https://developer.foursquare.com/docs/lists/update" class="auth noVenuesReq">update</a><br><a href="https://developer.foursquare.com/docs/lists/deleteitem" class="auth noVenuesReq">deleteitem</a><br><a href="https://developer.foursquare.com/docs/lists/updateitem" class="auth noVenuesReq">updateitem</a><br><a href="https://developer.foursquare.com/docs/lists/follow" class="auth noVenuesReq">follow</a><br><a href="https://developer.foursquare.com/docs/lists/unfollow" class="auth noVenuesReq">unfollow</a><br><a href="https://developer.foursquare.com/docs/lists/moveitem" class="auth noVenuesReq">moveitem</a><br><a href="https://developer.foursquare.com/docs/lists/share" class="auth noVenuesReq">share</a><br><a href="https://developer.foursquare.com/docs/lists/additem" class="auth noVenuesReq">additem</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/updates/updates" class="auth noVenuesReq">updates</a></th><td><a href="https://developer.foursquare.com/docs/updates/notifications" class="auth noVenuesReq">notifications</a></td><td></td><td><a href="https://developer.foursquare.com/docs/updates/marknotificationsread" class="auth noVenuesReq">marknotificationsread</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/photos/photos" class="auth noVenuesReq">photos</a></th><td><a href="https://developer.foursquare.com/docs/photos/add" class="auth noVenuesReq">add</a></td><td></td><td></td></tr><tr><th><a href="https://developer.foursquare.com/docs/settings/settings" class="auth noVenuesReq">settings</a></th><td><a href="https://developer.foursquare.com/docs/settings/all" class="auth noVenuesReq">all</a></td><td></td><td><a href="https://developer.foursquare.com/docs/settings/set" class="auth noVenuesReq">set</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/specials/specials" class="noAuth noVenuesReq">specials</a></th><td><a href="https://developer.foursquare.com/docs/specials/search" class="noAuth noVenuesReq">search</a><br><a href="https://developer.foursquare.com/docs/specials/list" class="auth venuesReq">list</a><br><a href="https://developer.foursquare.com/docs/specials/add" class="auth venuesReq">add</a></td><td></td><td><a href="https://developer.foursquare.com/docs/specials/flag" class="auth noVenuesReq">flag</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/events/events" class="auth noVenuesReq">events</a></th><td><a href="https://developer.foursquare.com/docs/events/search" class="noAuth noVenuesReq">search</a><br><a href="https://developer.foursquare.com/docs/events/categories" class="noAuth noVenuesReq">categories</a></td><td></td><td><a href="https://developer.foursquare.com/docs/events/add" class="auth venuesReq">add</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/pages/pages" class="auth noVenuesReq">pages</a></th><td><a href="https://developer.foursquare.com/docs/pages/managing" class="auth noVenuesReq">managing</a><br><a href="https://developer.foursquare.com/docs/pages/add" class="auth noVenuesReq">add</a></td><td><a href="https://developer.foursquare.com/docs/pages/similar" class="auth noVenuesReq">similar</a><br><a href="https://developer.foursquare.com/docs/pages/timeseries" class="auth venuesReq">timeseries</a><br><a href="https://developer.foursquare.com/docs/pages/access" class="auth noVenuesReq">access</a><br><a href="https://developer.foursquare.com/docs/pages/venues" class="noAuth noVenuesReq">venues</a></td><td><a href="https://developer.foursquare.com/docs/pages/follow" class="auth noVenuesReq">follow</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/pageupdates/pageupdates" class="auth noVenuesReq">pageupdates</a></th><td><a href="https://developer.foursquare.com/docs/pageupdates/list" class="auth noVenuesReq">list</a><br><a href="https://developer.foursquare.com/docs/pageupdates/add" class="auth noVenuesReq">add</a></td><td></td><td><a href="https://developer.foursquare.com/docs/pageupdates/like" class="auth noVenuesReq">like</a><br><a href="https://developer.foursquare.com/docs/pageupdates/delete" class="auth noVenuesReq">delete</a></td></tr><tr><th><a href="https://developer.foursquare.com/docs/multi/multi" class="auth noVenuesReq">multi</a></th><td></td><td></td><td></td></tr></tbody></table>
#
# ---

# %% [markdown]
# <a name = "Indy"></a>
# ## Data-Crawling with Foursquare (15 minutes)
#
# *Let's switch to our notebooks*
#
# > Discuss this in pairs with your table after reading the following question before moving on:
#
# Suppose we wanted to generate a list of venues for a given geographical boundary, such as our previously defined bounded box. How would we go about doing so?
#
# We could use a search procedure to go through the data bounded by a lat/long. First, we have to identify which columns we would like to include in our data frame.
#
# #### Create a DataFrame containing the following attributes:
#
#  - Lat
#  - Lon
#  - Name of Venue
#  - All of the data inside of "stats"

# %%
import pandas as pd

# Ok go for it!

# %% [markdown]
# An important method we will explore for the independent practice is 'nextvenue' method. You can find more info on this method in [these API notes](https://developer.foursquare.com/docs/venues/nextvenues). The 'nextvenue' method:
#
# > "Returns venues that people often check in to after the current venue. Up to 5 venues are returned in each query, and results are sorted by how many people have visited that venue after the current one. Homes are never returned in results."
#
# This method will form the kernel of a depth-first search procedure you will complete to crawl foursquare web-data.

# %% [markdown]
# ## Foursquare Independent Practice (10 min)
#
# To get more facility with Foursquare JSON structures, let's do a little practice. Select any resteraunt venue in your list of venues:
#
# ```python
#     client.venues('venue number here')
# ```
#
# Now, your task is to extract a list of comments, and only the comments from the JSON. You can use the json library in Python to help you visualize the data in a more organized manner, but nothing else.
#
# Now let's try something a bit more difficult. Select any venue in your list of venues:

# %%
import json

venue = client.venues('4ba8cefdf964a520a9f039e3')
client.venues('4ba8cefdf964a520a9f039e3')

venue['venue']['tips']['groups']

# Use the Json library to better output your json dump, otherwise it will take you forever to traverse the hierarchy
print(json.dumps(venue, indent = 4))

# Compare the nested data-structure, how would you go deeper to extract the comments?
print(json.dumps(venue['venue']['tips']['groups'], indent = 4))

#Voila! Simple, and elegant, but requires you to understand how the different data types are nested in each other
map(lambda h: h['text'], venue['venue']['tips']['groups'][0]['items'])
# Out:
# {
#     "venue": {
#         "rating": 7.0,
#         "hierarchy": [
#             {
#                 "lang": "en",
#                 "name": "Food Court - Mall of Georgia",
#                 "canonicalUrl": "https://foursquare.com/v/food-court--mall-of-georgia/4b48d042f964a520315826e3",
#                 "id": "4b48d042f964a520315826e3"
#             },
#             {
#                 "lang": "en",
#                 "name": "Mall of Georgia",
#                 "canonicalUrl": "https://foursquare.com/v/mall-of-georgia/4895a4f3f964a5206d511fe3",
#                 "id": "4895a4f3f964a5206d511fe3"
#             }
#         ],
#         "reasons": {
#             "count": 0,
#             "items": []
#         },
#         "likes": {
#             "count": 7,
#             "groups": [
#                 {
#                     "count": 7,
#                     "items": [
#                         {
#                             "gender": "male",
#                             "id": "710377",
#                             "firstName": "Daniel",
#                             "photo": {
#                                 "prefix": "https://irs0.4sqi.net/img/user/",
#                                 "suffix": "/710377-H0BSNXFZIZZC2TND.jpg"
#                             }
#                         },
#                         {
#                             "lastName": "Mills",
#                             "photo": {
#                                 "prefix": "https://irs2.4sqi.net/img/user/",
#                                 "suffix": "/FDX502DBWOXNDCR1.jpg"
#                             },
#                             "id": "3951828",
#                             "firstName": "Mary",
#                             "gender": "female"
#                         },
#                         {
#                             "lastName": "Cofer",
#                             "photo": {
#                                 "prefix": "https://irs2.4sqi.net/img/user/",
#                                 "suffix": "/11584889-ZZHTIVSCVQYWKDAH.jpg"
#                             },
#                             "id": "11584889",
#                             "firstName": "Joshua",
#                             "gender": "male"
#                         },
#                         {
#                             "lastName": "Thomas",
#                             "photo": {
#                                 "prefix": "https://irs2.4sqi.net/img/user/",
#                                 "suffix": "/45415535-1J0T1VRZ51YAPFOI.jpg"
#                             },
#                             "id": "45415535",
#                             "firstName": "Jeslyn",
#                             "gender": "female"
#                         }
#                     ],
#                     "type": "others"
#                 }
#             ],
#             "summary": "7 Likes"
#         },
#         "id": "4ba8cefdf964a520a9f039e3",
#         "createdAt": 1269354237,
#         "description": "Chick-fil-A is the nation's second-largest quick-service chicken restaurant chain. Fresh ingredients, tasty side dishes, desserts such as Hand-spun Milkshakes. Catering available.",
#         "verified": true,
#         "shortUrl": "http://4sq.com/9RgkSi",
#         "menu": {
#             "url": "http://www.chick-fil-a.com/Food/Menu",
#             "label": "Menu",
#             "mobileUrl": "http://www.chick-fil-a.com/Food/Menu",
#             "externalUrl": "http://www.chick-fil-a.com/Food/Menu",
#             "type": "Menu",
#             "anchor": "View Menu"
#         },
#         "hereNow": {
#             "count": 0,
#             "groups": [],
#             "summary": "Nobody here"
#         },
#         "allowMenuUrlEdit": true,
#         "pageUpdates": {
#             "count": 0,
#             "items": []
#         },
#         "contact": {
#             "phone": "6784826787",
#             "facebookUsername": "EatMorChikin",
#             "facebook": "313501065044",
#             "formattedPhone": "(678) 482-6787",
#             "facebookName": "Eat Mor Chikin Cowz"
#         },
#         "location": {
#             "city": "Buford",
#             "cc": "US",
#             "country": "United States",
#             "postalCode": "30519",
#             "state": "GA",
#             "formattedAddress": [
#                 "3333 Buford Dr Spc NO1071",
#                 "Buford, GA 30519",
#                 "United States"
#             ],
#             "address": "3333 Buford Dr Spc NO1071",
#             "lat": 34.06481882,
#             "lng": -83.98481369
#         },
#         "dislike": false,
#         "bestPhoto": {
#             "suffix": "/2VONpUQ47XlT0bmNx5IvMgT98TAMtn0y-QP6H0LOziI.jpg",
#             "width": 540,
#             "visibility": "public",
#             "height": 720,
#             "source": {
#                 "url": "https://foursquare.com/download/#/iphone",
#                 "name": "Foursquare for iOS"
#             },
#             "prefix": "https://irs1.4sqi.net/img/general/",
#             "id": "4f96abdce4b0b6acb2442d82",
#             "createdAt": 1335274460
#         },
#         "listed": {
#             "count": 1,
#             "groups": [
#                 {
#                     "count": 1,
#                     "items": [
#                         {
#                             "description": "",
#                             "collaborative": false,
#                             "url": "/melodybarker2/list/places",
#                             "editable": false,
#                             "listItems": {
#                                 "count": 170,
#                                 "items": [
#                                     {
#                                         "id": "v4ba8cefdf964a520a9f039e3",
#                                         "createdAt": 1365698441
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1361668085,
#                             "public": true,
#                             "followers": {
#                                 "count": 1
#                             },
#                             "user": {
#                                 "lastName": "Barker",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/28745300-TSW5E0IPX05FV0VO.jpg"
#                                 },
#                                 "id": "28745300",
#                                 "firstName": "Melody",
#                                 "gender": "female"
#                             },
#                             "updatedAt": 1417430298,
#                             "type": "others",
#                             "id": "512967f5e4b08ef063352516",
#                             "canonicalUrl": "https://foursquare.com/melodybarker2/list/places",
#                             "name": "places"
#                         }
#                     ],
#                     "type": "others",
#                     "name": "Lists from other people"
#                 }
#             ]
#         },
#         "canonicalUrl": "https://foursquare.com/v/chickfila/4ba8cefdf964a520a9f039e3",
#         "parent": {
#             "verified": false,
#             "name": "Food Court - Mall of Georgia",
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "location": {
#                 "city": "Buford",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "30519",
#                 "state": "GA",
#                 "formattedAddress": [
#                     "3333 Buford Dr",
#                     "Buford, GA 30519",
#                     "United States"
#                 ],
#                 "address": "3333 Buford Dr",
#                 "lat": 34.064853976146615,
#                 "lng": -83.98446292791112
#             },
#             "stats": {
#                 "tipCount": 18,
#                 "checkinsCount": 4896,
#                 "usersCount": 2256
#             },
#             "id": "4b48d042f964a520315826e3",
#             "categories": [
#                 {
#                     "pluralName": "Food Courts",
#                     "primary": true,
#                     "name": "Food Court",
#                     "shortName": "Food Court",
#                     "id": "4bf58dd8d48988d120951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         "tags": [
#             "chicken catering",
#             "chicken sandwich",
#             "family friendly"
#         ],
#         "price": {
#             "tier": 1,
#             "currency": "$",
#             "message": "Cheap"
#         },
#         "storeId": "1141",
#         "hours": {
#             "status": "Closed until 9:00 AM",
#             "timeframes": [
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "9:00 AM\u20139:00 PM"
#                         }
#                     ],
#                     "days": "Mon\u2013Sat",
#                     "includesToday": true
#                 }
#             ],
#             "isLocalHoliday": false,
#             "isOpen": false
#         },
#         "photos": {
#             "count": 5,
#             "groups": [
#                 {
#                     "count": 5,
#                     "items": [
#                         {
#                             "suffix": "/2VONpUQ47XlT0bmNx5IvMgT98TAMtn0y-QP6H0LOziI.jpg",
#                             "width": 540,
#                             "visibility": "public",
#                             "height": 720,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs1.4sqi.net/img/general/",
#                             "user": {
#                                 "lastName": "Wood-Phillips",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/IZKNUDBY5LJCHVTB.jpg"
#                                 },
#                                 "id": "1635789",
#                                 "firstName": "Juli",
#                                 "gender": "female"
#                             },
#                             "id": "4f96abdce4b0b6acb2442d82",
#                             "createdAt": 1335274460
#                         },
#                         {
#                             "suffix": "/6dgsbcSE-V_Q9t3Oz3nNEglbMRcf2bykN4aNSX1BFKk.jpg",
#                             "width": 405,
#                             "visibility": "public",
#                             "height": 720,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/android",
#                                 "name": "Foursquare for Android"
#                             },
#                             "prefix": "https://irs2.4sqi.net/img/general/",
#                             "user": {
#                                 "lastName": "Robinson",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/HNPW5TDUZLKOCOEJ.jpg"
#                                 },
#                                 "id": "34216387",
#                                 "firstName": "Frank",
#                                 "gender": "male"
#                             },
#                             "id": "5026c685e4b063baa1013a58",
#                             "createdAt": 1344718469
#                         },
#                         {
#                             "suffix": "/28745300_Q1PhrtoXO72_gjjBiNYH_lQr658m7AVvoRyy3sMVTBE.jpg",
#                             "width": 541,
#                             "visibility": "public",
#                             "height": 960,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/android",
#                                 "name": "Foursquare for Android"
#                             },
#                             "prefix": "https://irs3.4sqi.net/img/general/",
#                             "user": {
#                                 "lastName": "Barker",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/28745300-TSW5E0IPX05FV0VO.jpg"
#                                 },
#                                 "id": "28745300",
#                                 "firstName": "Melody",
#                                 "gender": "female"
#                             },
#                             "id": "5166e716e4b0ee275bbcf30a",
#                             "createdAt": 1365698326
#                         },
#                         {
#                             "suffix": "/28745300_-twMRtYRtEyRVSQym3acTIYiMO0-JTpc0U6MwoXoPQ0.jpg",
#                             "width": 960,
#                             "visibility": "public",
#                             "height": 576,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/android",
#                                 "name": "Foursquare for Android"
#                             },
#                             "prefix": "https://irs3.4sqi.net/img/general/",
#                             "user": {
#                                 "lastName": "Barker",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/28745300-TSW5E0IPX05FV0VO.jpg"
#                                 },
#                                 "id": "28745300",
#                                 "firstName": "Melody",
#                                 "gender": "female"
#                             },
#                             "id": "5166e9cbe4b0d8a0e12bf9dc",
#                             "createdAt": 1365699019
#                         },
#                         {
#                             "suffix": "/3044190_R0D0njgOq1JhskkK7by1of-gMJ7vRnq05Ix31UW4Uho.jpg",
#                             "width": 720,
#                             "visibility": "public",
#                             "height": 960,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs0.4sqi.net/img/general/",
#                             "user": {
#                                 "lastName": "Caldwell",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/EWOXYWLUMLS0YY4T.jpg"
#                                 },
#                                 "id": "3044190",
#                                 "firstName": "Joshua",
#                                 "gender": "male"
#                             },
#                             "id": "52728b8111d24c0efe3411ec",
#                             "createdAt": 1383238529
#                         }
#                     ],
#                     "type": "venue",
#                     "name": "Venue photos"
#                 }
#             ]
#         },
#         "attributes": {
#             "groups": [
#                 {
#                     "count": 1,
#                     "items": [
#                         {
#                             "displayValue": "$",
#                             "priceTier": 1,
#                             "displayName": "Price"
#                         }
#                     ],
#                     "type": "price",
#                     "name": "Price",
#                     "summary": "$"
#                 },
#                 {
#                     "count": 1,
#                     "items": [
#                         {
#                             "displayValue": "No",
#                             "displayName": "Outdoor Seating"
#                         }
#                     ],
#                     "type": "outdoorSeating",
#                     "name": "Outdoor Seating"
#                 },
#                 {
#                     "count": 8,
#                     "items": [
#                         {
#                             "displayValue": "Lunch",
#                             "displayName": "Lunch"
#                         },
#                         {
#                             "displayValue": "Dinner",
#                             "displayName": "Dinner"
#                         }
#                     ],
#                     "type": "serves",
#                     "name": "Menus",
#                     "summary": "Lunch & Dinner"
#                 }
#             ]
#         },
#         "stats": {
#             "tipCount": 6,
#             "checkinsCount": 806,
#             "visitsCount": 808,
#             "usersCount": 396
#         },
#         "tips": {
#             "count": 6,
#             "groups": [
#                 {
#                     "count": 6,
#                     "items": [
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4e189d4a091ada32262cc893",
#                             "text": "Chick-Fil-A is ALWAYS awesome!!!",
#                             "logView": true,
#                             "likes": {
#                                 "count": 3,
#                                 "groups": [
#                                     {
#                                         "count": 3,
#                                         "items": [
#                                             {
#                                                 "lastName": "Jones",
#                                                 "photo": {
#                                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                                     "suffix": "/85292613-AU2S4QLLGB5MNS21.jpg"
#                                                 },
#                                                 "id": "85292613",
#                                                 "firstName": "Zareth",
#                                                 "gender": "female"
#                                             },
#                                             {
#                                                 "gender": "female",
#                                                 "id": "22082748",
#                                                 "firstName": "ATLConnector",
#                                                 "photo": {
#                                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                                     "suffix": "/22082748-NTFGBDZPHDRXG5NW.jpg"
#                                                 }
#                                             },
#                                             {
#                                                 "lastName": "Fambrough",
#                                                 "photo": {
#                                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                                     "suffix": "/2ARI2LN145TM0KKK.jpg"
#                                                 },
#                                                 "id": "1116453",
#                                                 "firstName": "Jeff",
#                                                 "gender": "male"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "3 likes"
#                             },
#                             "type": "user",
#                             "id": "4e189d4a091ada32262cc893",
#                             "createdAt": 1310235978,
#                             "user": {
#                                 "lastName": "Manos",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/ESU53H5DPQFA1XKD.jpg"
#                                 },
#                                 "id": "11402636",
#                                 "firstName": "Julie (Karma Salon)",
#                                 "gender": "female"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4f49657ae4b0a34d387d4964",
#                             "text": "Best Sweet Tea Ever!",
#                             "logView": true,
#                             "likes": {
#                                 "count": 2,
#                                 "groups": [
#                                     {
#                                         "count": 2,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "2 likes"
#                             },
#                             "type": "user",
#                             "id": "4f49657ae4b0a34d387d4964",
#                             "createdAt": 1330210170,
#                             "user": {
#                                 "lastName": "G",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/SK1B2KZN1JS1CARA.jpg"
#                                 },
#                                 "id": "649594",
#                                 "firstName": "Chris",
#                                 "gender": "male"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4f5fc116e4b0f5c1d19b11f7",
#                             "text": "No more mall employee discount :(",
#                             "logView": true,
#                             "likes": {
#                                 "count": 1,
#                                 "groups": [
#                                     {
#                                         "count": 1,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "1 like"
#                             },
#                             "type": "user",
#                             "id": "4f5fc116e4b0f5c1d19b11f7",
#                             "createdAt": 1331675414,
#                             "user": {
#                                 "lastName": "Howington",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/DDLU4SBEWV15DVG4.jpg"
#                                 },
#                                 "id": "4339466",
#                                 "firstName": "Randy",
#                                 "gender": "male"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4bc5d6d170c603bbd8cf97b4",
#                             "text": "You can always trade the kids meal toy for a small ice cream cone.",
#                             "logView": true,
#                             "likes": {
#                                 "count": 1,
#                                 "groups": [
#                                     {
#                                         "count": 1,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "1 like"
#                             },
#                             "type": "user",
#                             "id": "4bc5d6d170c603bbd8cf97b4",
#                             "createdAt": 1271256785,
#                             "user": {
#                                 "lastName": "Sanalila",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/4WOIWD5C4V2CQHGV.jpg"
#                                 },
#                                 "id": "904320",
#                                 "firstName": "Alfred",
#                                 "gender": "male"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/520052a0498eed21f8d28a84",
#                             "text": "Twice in one week they messed up my daughters order, then the manager defends the employee rather than apologize.   Hamilton Mill restaurant is  way better with way better customer service!",
#                             "logView": true,
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "520052a0498eed21f8d28a84",
#                             "createdAt": 1375752864,
#                             "user": {
#                                 "lastName": "Prendergast",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/4MTWW0Z13MUF5ABB.jpg"
#                                 },
#                                 "id": "48351856",
#                                 "firstName": "Mary Ann",
#                                 "gender": "female"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/5166e778e4b0d8a0e115ab3d",
#                             "text": "There using iPads to take orders. Face to face. ^_^",
#                             "logView": true,
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "5166e778e4b0d8a0e115ab3d",
#                             "createdAt": 1365698424,
#                             "user": {
#                                 "lastName": "Barker",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/28745300-TSW5E0IPX05FV0VO.jpg"
#                                 },
#                                 "id": "28745300",
#                                 "firstName": "Melody",
#                                 "gender": "female"
#                             }
#                         }
#                     ],
#                     "type": "others",
#                     "name": "All tips"
#                 }
#             ]
#         },
#         "categories": [
#             {
#                 "pluralName": "Fast Food Restaurants",
#                 "primary": true,
#                 "name": "Fast Food Restaurant",
#                 "shortName": "Fast Food",
#                 "id": "4bf58dd8d48988d16e941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fastfood_",
#                     "suffix": ".png"
#                 }
#             },
#             {
#                 "shortName": "American",
#                 "pluralName": "American Restaurants",
#                 "id": "4bf58dd8d48988d14e941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                     "suffix": ".png"
#                 },
#                 "name": "American Restaurant"
#             },
#             {
#                 "shortName": "Sandwiches",
#                 "pluralName": "Sandwich Places",
#                 "id": "4bf58dd8d48988d1c5941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
#                     "suffix": ".png"
#                 },
#                 "name": "Sandwich Place"
#             }
#         ],
#         "ok": false,
#         "name": "Chick-fil-A",
#         "url": "http://www.chick-fil-a.com/mallofgeorgia",
#         "phrases": [
#             {
#                 "sample": {
#                     "entities": [
#                         {
#                             "indices": [
#                                 25,
#                                 39
#                             ],
#                             "type": "keyPhrase"
#                         }
#                     ],
#                     "text": "... meal toy for a small ice cream cone."
#                 },
#                 "phrase": "ice cream cone",
#                 "count": 1
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "venueChains": [
#             {
#                 "logo": {
#                     "prefix": "https://irs1.4sqi.net/img/user/",
#                     "suffix": "/32440041-L03XUZYWBLKTSEJF.png"
#                 },
#                 "id": "556e1846a7c82e6b72513d6b",
#                 "bestName": {
#                     "lang": "en",
#                     "name": "Chick-fil-A"
#                 }
#             }
#         ],
#         "ratingColor": "C5DE35",
#         "ratingSignals": 13,
#         "popular": {
#             "timeframes": [
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "9:00 AM\u20137:00 PM"
#                         }
#                     ],
#                     "days": "Today",
#                     "includesToday": true
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "10:00 AM\u20139:00 PM"
#                         }
#                     ],
#                     "days": "Thu"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "9:00 AM\u20139:00 PM"
#                         }
#                     ],
#                     "days": "Fri\u2013Sat"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "None"
#                         }
#                     ],
#                     "days": "Sun"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "9:00 AM\u20138:00 PM"
#                         }
#                     ],
#                     "days": "Mon\u2013Tue"
#                 }
#             ],
#             "isLocalHoliday": false,
#             "isOpen": false
#         },
#         "timeZone": "America/New_York",
#         "page": {
#             "pageInfo": {
#                 "description": "Your local Chick-fil-A has something for everyone, including our signature chicken sandwich, wraps, desserts, and more. We also cater! Contact us to inquire.",
#                 "links": {
#                     "count": 1,
#                     "items": [
#                         {
#                             "url": "http://www.chick-fil-a.com/parksidetowncommons"
#                         }
#                     ]
#                 }
#             },
#             "user": {
#                 "bio": "",
#                 "firstName": "Chick-fil-A",
#                 "gender": "none",
#                 "lists": {
#                     "groups": [
#                         {
#                             "count": 2,
#                             "items": [],
#                             "type": "created"
#                         }
#                     ]
#                 },
#                 "homeCity": "Atlanta, GA",
#                 "contact": {
#                     "facebook": "313501065044"
#                 },
#                 "photo": {
#                     "prefix": "https://irs1.4sqi.net/img/user/",
#                     "suffix": "/32440041-L03XUZYWBLKTSEJF.png"
#                 },
#                 "tips": {
#                     "count": 163
#                 },
#                 "type": "chain",
#                 "id": "32440041"
#             }
#         },
#         "inbox": {
#             "count": 0,
#             "items": []
#         }
#     }
# }
# [
#     {
#         "count": 6,
#         "items": [
#             {
#                 "lang": "en",
#                 "todo": {
#                     "count": 0
#                 },
#                 "canonicalUrl": "https://foursquare.com/item/4e189d4a091ada32262cc893",
#                 "text": "Chick-Fil-A is ALWAYS awesome!!!",
#                 "logView": true,
#                 "likes": {
#                     "count": 3,
#                     "groups": [
#                         {
#                             "count": 3,
#                             "items": [
#                                 {
#                                     "lastName": "Jones",
#                                     "photo": {
#                                         "prefix": "https://irs3.4sqi.net/img/user/",
#                                         "suffix": "/85292613-AU2S4QLLGB5MNS21.jpg"
#                                     },
#                                     "id": "85292613",
#                                     "firstName": "Zareth",
#                                     "gender": "female"
#                                 },
#                                 {
#                                     "gender": "female",
#                                     "id": "22082748",
#                                     "firstName": "ATLConnector",
#                                     "photo": {
#                                         "prefix": "https://irs3.4sqi.net/img/user/",
#                                         "suffix": "/22082748-NTFGBDZPHDRXG5NW.jpg"
#                                     }
#                                 },
#                                 {
#                                     "lastName": "Fambrough",
#                                     "photo": {
#                                         "prefix": "https://irs3.4sqi.net/img/user/",
#                                         "suffix": "/2ARI2LN145TM0KKK.jpg"
#                                     },
#                                     "id": "1116453",
#                                     "firstName": "Jeff",
#                                     "gender": "male"
#                                 }
#                             ],
#                             "type": "others"
#                         }
#                     ],
#                     "summary": "3 likes"
#                 },
#                 "type": "user",
#                 "id": "4e189d4a091ada32262cc893",
#                 "createdAt": 1310235978,
#                 "user": {
#                     "lastName": "Manos",
#                     "photo": {
#                         "prefix": "https://irs3.4sqi.net/img/user/",
#                         "suffix": "/ESU53H5DPQFA1XKD.jpg"
#                     },
#                     "id": "11402636",
#                     "firstName": "Julie (Karma Salon)",
#                     "gender": "female"
#                 }
#             },
#             {
#                 "lang": "en",
#                 "todo": {
#                     "count": 0
#                 },
#                 "canonicalUrl": "https://foursquare.com/item/4f49657ae4b0a34d387d4964",
#                 "text": "Best Sweet Tea Ever!",
#                 "logView": true,
#                 "likes": {
#                     "count": 2,
#                     "groups": [
#                         {
#                             "count": 2,
#                             "items": [],
#                             "type": "others"
#                         }
#                     ],
#                     "summary": "2 likes"
#                 },
#                 "type": "user",
#                 "id": "4f49657ae4b0a34d387d4964",
#                 "createdAt": 1330210170,
#                 "user": {
#                     "lastName": "G",
#                     "photo": {
#                         "prefix": "https://irs3.4sqi.net/img/user/",
#                         "suffix": "/SK1B2KZN1JS1CARA.jpg"
#                     },
#                     "id": "649594",
#                     "firstName": "Chris",
#                     "gender": "male"
#                 }
#             },
#             {
#                 "lang": "en",
#                 "todo": {
#                     "count": 0
#                 },
#                 "canonicalUrl": "https://foursquare.com/item/4f5fc116e4b0f5c1d19b11f7",
#                 "text": "No more mall employee discount :(",
#                 "logView": true,
#                 "likes": {
#                     "count": 1,
#                     "groups": [
#                         {
#                             "count": 1,
#                             "items": [],
#                             "type": "others"
#                         }
#                     ],
#                     "summary": "1 like"
#                 },
#                 "type": "user",
#                 "id": "4f5fc116e4b0f5c1d19b11f7",
#                 "createdAt": 1331675414,
#                 "user": {
#                     "lastName": "Howington",
#                     "photo": {
#                         "prefix": "https://irs0.4sqi.net/img/user/",
#                         "suffix": "/DDLU4SBEWV15DVG4.jpg"
#                     },
#                     "id": "4339466",
#                     "firstName": "Randy",
#                     "gender": "male"
#                 }
#             },
#             {
#                 "lang": "en",
#                 "todo": {
#                     "count": 0
#                 },
#                 "canonicalUrl": "https://foursquare.com/item/4bc5d6d170c603bbd8cf97b4",
#                 "text": "You can always trade the kids meal toy for a small ice cream cone.",
#                 "logView": true,
#                 "likes": {
#                     "count": 1,
#                     "groups": [
#                         {
#                             "count": 1,
#                             "items": [],
#                             "type": "others"
#                         }
#                     ],
#                     "summary": "1 like"
#                 },
#                 "type": "user",
#                 "id": "4bc5d6d170c603bbd8cf97b4",
#                 "createdAt": 1271256785,
#                 "user": {
#                     "lastName": "Sanalila",
#                     "photo": {
#                         "prefix": "https://irs0.4sqi.net/img/user/",
#                         "suffix": "/4WOIWD5C4V2CQHGV.jpg"
#                     },
#                     "id": "904320",
#                     "firstName": "Alfred",
#                     "gender": "male"
#                 }
#             },
#             {
#                 "lang": "en",
#                 "todo": {
#                     "count": 0
#                 },
#                 "canonicalUrl": "https://foursquare.com/item/520052a0498eed21f8d28a84",
#                 "text": "Twice in one week they messed up my daughters order, then the manager defends the employee rather than apologize.   Hamilton Mill restaurant is  way better with way better customer service!",
#                 "logView": true,
#                 "likes": {
#                     "count": 0,
#                     "groups": []
#                 },
#                 "type": "user",
#                 "id": "520052a0498eed21f8d28a84",
#                 "createdAt": 1375752864,
#                 "user": {
#                     "lastName": "Prendergast",
#                     "photo": {
#                         "prefix": "https://irs2.4sqi.net/img/user/",
#                         "suffix": "/4MTWW0Z13MUF5ABB.jpg"
#                     },
#                     "id": "48351856",
#                     "firstName": "Mary Ann",
#                     "gender": "female"
#                 }
#             },
#             {
#                 "lang": "en",
#                 "todo": {
#                     "count": 0
#                 },
#                 "canonicalUrl": "https://foursquare.com/item/5166e778e4b0d8a0e115ab3d",
#                 "text": "There using iPads to take orders. Face to face. ^_^",
#                 "logView": true,
#                 "likes": {
#                     "count": 0,
#                     "groups": []
#                 },
#                 "type": "user",
#                 "id": "5166e778e4b0d8a0e115ab3d",
#                 "createdAt": 1365698424,
#                 "user": {
#                     "lastName": "Barker",
#                     "photo": {
#                         "prefix": "https://irs2.4sqi.net/img/user/",
#                         "suffix": "/28745300-TSW5E0IPX05FV0VO.jpg"
#                     },
#                     "id": "28745300",
#                     "firstName": "Melody",
#                     "gender": "female"
#                 }
#             }
#         ],
#         "type": "others",
#         "name": "All tips"
#     }
# ]
# [u'Chick-Fil-A is ALWAYS awesome!!!',
#  u'Best Sweet Tea Ever!',
#  u'No more mall employee discount :(',
#  u'You can always trade the kids meal toy for a small ice cream cone.',
#  u'Twice in one week they messed up my daughters order, then the manager defends the employee rather than apologize.   Hamilton Mill restaurant is  way better with way better customer service!',
#  u'There using iPads to take orders. Face to face. ^_^']

# %% [markdown]
# <a name = "conclusion"></a>
# ## Conclusion (5 min)
#
# Some parting thoughts on today's activities:
#
# - Describe what an API allows you to do?
# - How does an API response compare with a HTTP response in the browser?
# - In what format is the data returned?
#
# Excellent, we have done a lot in learning about the Foursquare API , and we now have a data set we can use for basic analysis. In the lab, we will engage in some exploratory analysis, and explore foursquare data more!

# %% [markdown]
# ### ADDITIONAL RESOURCES
#
# - [Working with APIs](https://zapier.com/learn/apis/chapter-1-introduction-to-apis/)
# - [Foursquare Developer API docs](https://developer.foursquare.com)
