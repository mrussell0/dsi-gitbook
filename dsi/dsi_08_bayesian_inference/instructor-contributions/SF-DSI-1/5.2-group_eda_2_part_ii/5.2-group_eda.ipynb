# %% [markdown]
# <img src="https://i.imgflip.com/14vp9i.jpg" width="400" style="float: right; margin: 50px">
#
# # GROUP EDA
#
# Today we will be splitting into 4 groups and presenting our findings the last hour of class.
#
# The goals for todays activity include:
#
# - Defining a problem statement as a group
# - Exloring datasets and practicing exploratory analysis
# - Good use of validation
# - Communicating results succinctly
#
# You might consider preparing a brief slide deck, but it's not necessary.  We created [these great guidelines](https://github.com/ga-students/DSI-SF-1/wiki/Presentation-Guidelines) to help.
#
# ## Deliverables
#
# - 10 Minute presentation, 5 minutes question and answer
# - Validation of results
#
# ### Optional Feedback
#
# After presentations, please give feedback to each other.
#
# - Peer feedback:  [Use this form](http://goo.gl/forms/ybRIcrwYrVVV4hhR2).  All responses are shared.  Be nice ;)
#
# ### Suggestions
# - Appoint someone to present / organize
# - Look at summary statistics, explore data
# - Refine problem statement
# - Divide and conquer your workload
# - Don't fight - you will be held accountable for presenting _something_.
# - You will present

# %% [markdown]
# ## Group 1:  WOW
#
# <img src="https://snag.gy/tZXe0N.jpg" width="500">

# %% [markdown]
# Using [this dataset](https://www.kaggle.com/mylesoneill/warcraft-avatar-history/downloads/warcraft-avatar-history.zip), we would like you to figure out if the following is possible:
#
# 1. Predict when a user has "churned" or will churn.  We want to know about churn!  What is this about, you will have to research this idea if it is unfamilliar to you.  We want that \$\$\$\$ so help us deal with churn!<br><br>
#
# 1. Also, we want to know more about zones and player classes.  We have a hunch something good is happening there.<br><br>
#
# 1. Is there anything else we can do to optimize gameplay?<br><br>
#
# 1. We're thinking about making yet another expansion.  Are there any themes we might consider based on player behavior *ie: which features are important to consider about current player preferences to ______*?
#
# ** Projected Challenges **
# - Research
# - Problem statement expected to be much more defined
# - There are a lot of areas to explore and focus may be difficult without a plan

# %% [markdown]
# ## Group 2: GOT
#
# <img src="https://snag.gy/8uoD9y.jpg" width="500">
#
# Using [this dataset](./assets/datasets/character-predictions.csv), we would like to know which factors are most important predictors of mortality within our population.  From what we know, this dataset was scraped from [this website](http://awoiaf.westeros.org/index.php/Main_Page) and may provide pointers on the definition of the dataset.
#
# **Projected Challeneges**
# - Some munging
# - Regression and classification type problems possible
# - Data is not as cut and dry as it seems

# %% [markdown]
# ## Group 3:  Last Words
#
# <img src="https://snag.gy/MElcUY.jpg" width="200">
#
# Using [this dataset](https://docs.google.com/spreadsheet/ccc?key=0ArNsipRBvi69dEUxZHVuRTc4ZlctREdldExsOW5rMUE#gid=0), we would like you to approach this as a study that might inform policy in how law is applied.  The first step in this process, let's assume, is a high level report that illustrates any commonalities and patterns found in this dataset
# :
#
# - Common patterns found in last words of inmates
# - Commonality of words to other features in dataset
# - Of lessor importance, how hard would it be to classify religious inclinations
# - Sentiment as a feature or frequency (ie: Check out textblob - pip install textblob)
#  - Can this be stratified to other features
#  - Which words seem to be common in these cases
#
# ** Bonus **
# Do any POS patterns look interesting?
#
# **Projected Challenges**
#  - Problem statement may be challenging but you will need to come up with one
#  - This project is a bit more defined but there are vague problems involved
#  - There are a lot of vague asks
#  - Heavily NLP based problem

# %% [markdown]
# ## Group 4: Indeed, you need a job
#
# <img src="https://lh5.googleusercontent.com/CJwGV91wfvsEsDqCBjsg2ahGKAoP2_Wwd3JXXBb8yWPlIT676LlBnsIfG2bFUtOxgLb0ba5WJKfzMiVdT9ncQhSmscdcxPZDnWfV6Qkb0LhR_6Natug72_MsYTLDJS34vg" width="500">
#
# You need a job.  There are lots of jobs with the title "Data Scientist".  There are other jobs as well that have the same skillset.  Recently we [scraped together a dataset](assets/datasets/indeed.csv), that is not super clean but will work.
#
# Which jobs aren't labeled like "data science" jobs, but have a lot of the same features found in "data scientist" jobs?
#
#  - Who is hiring the most? (this may be difficult without updating our scraper and getting more data, but we'll say this is optional)
#  - Which skills seem more important to big / medium / small companies or less well known?
#  - Which keywords are commmon?
#  - Which are rare?
#
# **Projected Challenges**
# - Labeled data is based on search terms and results may overlap quite a bit
#  - Some cleaning
# - Great opportunity to practice NLP
# - DO NGRAM ANALYSIS OR ELSE!
#
# PLEASE share your notebooks with the rest of class.  This type of analysis will give you an edge in the job market and lead you to other areas to explore / mine / predict.

# %%
import imdb

ia = imdb.IMDb()
result = ia.search_movie('The Untouchables')
for item in result:
    print item
# Out:
# The Untouchables
# The Untouchables
# The Untouchables
# The Untouchables
# The Intouchables
# Untouchable
# The Untouchables
# Untouchable (I)
# The Untouchable
# Untouchable
# The Untouchable 2
# Untouchable
# The Untouchables
# Untouchable
# Untouchable
# Untouchable (I)
# The Untouchables
# The Untouchables
# The Untouchables
# The Untouchables

# %%
# Get the first item from results
movie = result[0]
ia.update(movie)

# %%
print vars(movie)
# Out:
# {'_roleIsPerson': False, '_roleClass': <class 'imdb.Character.Character'>, 'movieID': '0094226', 'infoset2keys': {'plot': ['plot'], 'main': [u'music department', 'votes', 'camera and electrical department', u'distributors', 'rating', 'runtimes', 'production manager', 'costume designer', 'original music', 'make up', 'year', 'miscellaneous crew', u'production companies', 'color info', u'casting department', 'languages', 'genres', 'producer', 'title', 'assistant director', 'special effects companies', 'casting director', 'visual effects', 'writer', 'set decoration', 'editor', 'certificates', u'costume department', 'country codes', 'language codes', 'cover url', u'special effects department', u'editorial department', 'sound mix', 'director', 'stunt performer', 'miscellaneous companies', 'cinematographer', 'art direction', 'sound crew', 'akas', 'aspect ratio', u'art department', 'kind', 'countries', u'transportation department', 'plot outline', 'cast']}, 'current_info': ['main', 'plot'], 'keys_tomodify': {'crazy credits': None, 'plot': None, 'business': None, 'dvd': None, 'video review': None, 'alternate versions': None, 'soundtrack': None, 'quotes': None, 'supplements': None, 'news': None, 'goofs': None, 'trivia': None, 'faqs': None, 'laserdisc': None}, 'notes': u'', 'key2infoset': {u'music department': 'main', u'distributors': 'main', 'rating': 'main', 'runtimes': 'main', 'costume designer': 'main', 'make up': 'main', 'year': 'main', 'miscellaneous crew': 'main', 'aspect ratio': 'main', 'casting director': 'main', u'special effects department': 'main', 'visual effects': 'main', 'votes': 'main', 'producer': 'main', 'title': 'main', 'assistant director': 'main', 'writer': 'main', 'kind': 'main', 'color info': 'main', 'languages': 'main', 'production manager': 'main', 'set decoration': 'main', 'editor': 'main', 'certificates': 'main', u'costume department': 'main', 'country codes': 'main', 'language codes': 'main', 'cover url': 'main', u'casting department': 'main', 'special effects companies': 'main', 'sound mix': 'main', 'genres': 'main', u'production companies': 'main', 'stunt performer': 'main', 'miscellaneous companies': 'main', 'cinematographer': 'main', 'art direction': 'main', 'akas': 'main', 'sound crew': 'main', 'director': 'main', 'camera and electrical department': 'main', u'art department': 'main', 'countries': 'main', u'transportation department': 'main', 'plot outline': 'main', 'plot': 'plot', 'cast': 'main', 'original music': 'main', u'editorial department': 'main'}, 'myTitle': u'', 'charactersRefs': {}, 'accessSystem': 'http', 'namesRefs': {}, 'myID': None, '_Container__role': None, 'titlesRefs': {}, 'data': {u'music department': [<Person id:0152940[http] name:_Charlap, Emile_>, <Person id:0237515[http] name:_Drescher, Thomas S._>, <Person id:0268520[http] name:_Farrow, Michael_>, <Person id:0309154[http] name:_Gaskins, Rudy_>, <Person id:0001553[http] name:_Morricone, Ennio_>, <Person id:0001553[http] name:_Morricone, Ennio_>, <Person id:3212883[http] name:_Bulk, Neil S._>, <Person id:0298107[http] name:_Fulginiti, Greg_>, <Person id:1161586[http] name:_Goldwasser, Dan_>, <Person id:0608585[http] name:_Moses, John_>], 'sound crew': [<Person id:0073490[http] name:_Berenbaum, Michael_>, <Person id:0083680[http] name:_Birnbaum, Elisha_>, <Person id:0108403[http] name:_Briamonte, Amy_>, <Person id:0225751[http] name:_DiCosimo, Michael_>, <Person id:0232570[http] name:_Donlan, Gerald_>, <Person id:0263105[http] name:_Evans, Noreen_>, <Person id:0275779[http] name:_Fidlow, Harriet_>, <Person id:0280657[http] name:_Fitzstephens, Jack_>, <Person id:0418374[http] name:_Janus, Dale R._>, <Person id:0428061[http] name:_Jones, Faith_>, <Person id:0497678[http] name:_Lee, Kevin_>, <Person id:0624913[http] name:_Nejad, Abe_>, <Person id:0689310[http] name:_Polk, Ken S._>, <Person id:0705242[http] name:_Rackow, Sanford_>, <Person id:0754797[http] name:_Sable, Dan_>, <Person id:0002361[http] name:_Sable, Lynn_>, <Person id:0780671 ...

# %%
from imdbpie import Imdb

imdb = Imdb()
top_100 = imdb.top_250()[:100]
# top_100 = top_250[:100]
# #This is code to scrape the first page of the reviews section for a film.
# first_page_reviews = []
# for x in top_100['tconst']:
#     response = requests.get('http://www.imdb.com/title/%s/reviews?ref_=tt_urv' % x)
#     HTML = response.text
#     review_first_page = Selector(text=HTML).xpath('//*[@id="tn15content"]/p').extract()
#     first_page_reviews.append(review_first_page)
# # Code to scrape the star ratings on user reivews
# ratings = []
# for x in top_100['tconst']:
#     response = requests.get('http://www.imdb.com/title/%s/reviews?ref_=tt_urv' % x)
#     HTML = response.text
#     rating = Selector(text=HTML).xpath('//*[@id="tn15content"]/div/img/@alt').extract()


#     ratings.append(rating)

# %%
movie_reviews = imdb.get_title_reviews("tt0068646", max_results=500)

for review in movie_reviews:
    print review.rating
# Out:
# 500

# %%
top_100
# Out:
# [{u'can_rate': True,
#   u'image': {u'height': 1388,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_.jpg',
#    u'width': 933},
#   u'num_votes': 1659874,
#   u'rating': 9.3,
#   u'tconst': u'tt0111161',
#   u'title': u'The Shawshank Redemption',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjEyMjcyNDI4MF5BMl5BanBnXkFtZTcwMDA5Mzg3OA@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 1136115,
#   u'rating': 9.2,
#   u'tconst': u'tt0068646',
#   u'title': u'The Godfather',
#   u'type': u'feature',
#   u'year': u'1972'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDc2NTM3MzU1Nl5BMl5BanBnXkFtZTcwMTA5Mzg3OA@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 775937,
#   u'rating': 9,
#   u'tconst': u'tt0071562',
#   u'title': u'The Godfather: Part II',
#   u'type': u'feature',
#   u'year': u'1974'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_.jpg',
#    u'width': 1383},
#   u'num_votes': 1645562,
#   u'rating': 9,
#   u'tconst': u'tt0468569',
#   u'title': u'The Dark Knight',
#   u'type': u'feature',
#   u'year': u'2008'},
#  {u'can_rate': True,
#   u'image': {u'height': 679,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMzMwMTM4MDU2N15BMl5BanBnXkFtZTgwMzQ0MjMxMDE@._V1_.jpg',
#    u'width': 439},
#   u'num_votes': 849170,
#   u'rating': 8.9,
#   u'tconst': u'tt0108052',
#   u'title': u"Schindler's List",
#   u'type': u'feature',
#   u'year': u'1993'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BODQwOTc5MDM2N15BMl5BanBnXkFtZTcwODQxNTEzNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 437815,
#   u'rating': 8.9,
#   u'tconst': u'tt0050083',
#   u'title': u'12 Angry Men',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkxMTA5OTAzMl5BMl5BanBnXkFtZTgwNjA5MDc3NjE@._V1_.jpg',
#    u'width': 1010},
#   u'num_votes': 1300853,
#   u'rating': 8.9,
#   u'tconst': u'tt0110912',
#   u'title': u'Pulp Fiction',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 519,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjE4MjA1NTAyMV5BMl5BanBnXkFtZTcwNzM1NDQyMQ@@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 1194499,
#   u'rating': 8.9,
#   u'tconst': u'tt0167260',
#   u'title': u'The Lord of the Rings: The Return of the King',
#   u'type': u'feature',
#   u'year': u'2003'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BOTQ5NDI3MTI4MF5BMl5BanBnXkFtZTgwNDQ4ODE5MDE@._V1_.jpg',
#    u'width': 1344},
#   u'num_votes': 494801,
#   u'rating': 8.9,
#   u'tconst': u'tt0060196',
#   u'title': u'The Good, the Bad and the Ugly',
#   u'type': u'feature',
#   u'year': u'1966'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIwNTYzMzE1M15BMl5BanBnXkFtZTcwOTE5Mzg3OA@@._V1_.jpg',
#    u'width': 336},
#   u'num_votes': 1321533,
#   u'rating': 8.9,
#   u'tconst': u'tt0137523',
#   u'title': u'Fight Club',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNTEyMjAwMDU1OV5BMl5BanBnXkFtZTcwNDQyNTkxMw@@._V1_.jpg',
#    u'width': 342},
#   u'num_votes': 1217945,
#   u'rating': 8.8,
#   u'tconst': u'tt0120737',
#   u'title': u'The Lord of the Rings: The Fellowship of the Ring',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjE2MzQwMTgxN15BMl5BanBnXkFtZTcwMDQzNjk2OQ@@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 821189,
#   u'rating': 8.8,
#   u'tconst': u'tt0080684',
#   u'title': u'Star Wars: Episode V - The Empire Strikes Back',
#   u'type': u'feature',
#   u'year': u'1980'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTI1Nzk1MzQwMV5BMl5BanBnXkFtZTYwODkxOTA5._V1_.jpg',
#    u'width': 331},
#   u'num_votes': 1224755,
#   u'rating': 8.8,
#   u'tconst': u'tt0109830',
#   u'title': u'Forrest Gump',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 1037,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_.jpg',
#    u'width': 700},
#   u'num_votes': 1439119,
#   u'rating': 8.8,
#   u'tconst': u'tt1375666',
#   u'title': u'Inception',
#   u'type': u'feature',
#   u'year': u'2010'},
#  {u'can_rate': True,
#   u'image': {u'height': 512,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTAyNDU0NjY4NTheQTJeQWpwZ15BbWU2MDk4MTY2Nw@@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 1080649,
#   u'rating': 8.7,
#   u'tconst': u'tt0167261',
#   u'title': u'The Lord of the Rings: The Two Towers',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk5OTA4NTc0NF5BMl5BanBnXkFtZTcwNzI5Mzg3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 668554,
#   u'rating': 8.7,
#   u'tconst': u'tt0073486',
#   u'title': u"One Flew Over the Cuckoo's Nest",
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY2OTE5MzQ3MV5BMl5BanBnXkFtZTgwMTY2NTYxMTE@._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 715531,
#   u'rating': 8.7,
#   u'tconst': u'tt0099685',
#   u'title': u'Goodfellas',
#   u'type': u'feature',
#   u'year': u'1990'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkxNDYxOTA4M15BMl5BanBnXkFtZTgwNTk0NzQxMTE@._V1_.jpg',
#    u'width': 334},
#   u'num_votes': 1196100,
#   u'rating': 8.7,
#   u'tconst': u'tt0133093',
#   u'title': u'The Matrix',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 1900,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc5MDY1MjU5MF5BMl5BanBnXkFtZTgwNDM2OTE4MzE@._V1_.jpg',
#    u'width': 1354},
#   u'num_votes': 225359,
#   u'rating': 8.7,
#   u'tconst': u'tt0047478',
#   u'title': u'Seven Samurai',
#   u'type': u'feature',
#   u'year': u'1954'},
#  {u'can_rate': True,
#   u'image': {u'height': 1270,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BOTIyMDY2NGQtOGJjNi00OTk4LWFhMDgtYmE3M2NiYzM0YTVmXkEyXkFqcGdeQXVyNTU1NTcwOTk@._V1_.jpg',
#    u'width': 831},
#   u'num_votes': 894789,
#   u'rating': 8.7,
#   u'tconst': u'tt0076759',
#   u'title': u'Star Wars',
#   u'type': u'feature',
#   u'year': u'1977'},
#  {u'can_rate': True,
#   u'image': {u'height': 593,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA4ODQ3ODkzNV5BMl5BanBnXkFtZTYwOTc4NDI3._V1_.jpg',
#    u'width': 400},
#   u'num_votes': 524579,
#   u'rating': 8.7,
#   u'tconst': u'tt0317248',
#   u'title': u'City of God',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQwNTU3MTE4NF5BMl5BanBnXkFtZTcwOTgxNDM2Mg@@._V1_.jpg',
#    u'width': 326},
#   u'num_votes': 1003992,
#   u'rating': 8.6,
#   u'tconst': u'tt0114369',
#   u'title': u'Se7en',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ2NzkzMDI4OF5BMl5BanBnXkFtZTcwMDA0NzE1NA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 869224,
#   u'rating': 8.6,
#   u'tconst': u'tt0102926',
#   u'title': u'The Silence of the Lambs',
#   u'type': u'feature',
#   u'year': u'1991'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTMzMzY5NDc4M15BMl5BanBnXkFtZTcwMzc4NjIxNw@@._V1_.jpg',
#    u'width': 1372},
#   u'num_votes': 271031,
#   u'rating': 8.6,
#   u'tconst': u'tt0038650',
#   u'title': u"It's a Wonderful Life",
#   u'type': u'feature',
#   u'year': u'1946'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMzI1MjI5MDQyOV5BMl5BanBnXkFtZTcwNzE4Mjg3NA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 727832,
#   u'rating': 8.6,
#   u'tconst': u'tt0114814',
#   u'title': u'The Usual Suspects',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQwMTM2MjE4Ml5BMl5BanBnXkFtZTgwODQ2NTYxMTE@._V1_.jpg',
#    u'width': 334},
#   u'num_votes': 410842,
#   u'rating': 8.6,
#   u'tconst': u'tt0118799',
#   u'title': u'Life Is Beautiful',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgzMzg4MDkwNF5BMl5BanBnXkFtZTcwODAwNDg3OA@@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 711822,
#   u'rating': 8.6,
#   u'tconst': u'tt0110413',
#   u'title': u'L\xe9on: The Professional',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTEyODQzNDkzNjVeQTJeQWpwZ15BbWU4MDgyODk1NDEx._V1_.jpg',
#    u'width': 352},
#   u'num_votes': 212209,
#   u'rating': 8.6,
#   u'tconst': u'tt0064116',
#   u'title': u'Once Upon a Time in the West',
#   u'type': u'feature',
#   u'year': u'1968'},
#  {u'can_rate': True,
#   u'image': {u'height': 635,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjYxMDcyMzIzNl5BMl5BanBnXkFtZTYwNDg2MDU3._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 407981,
#   u'rating': 8.6,
#   u'tconst': u'tt0245429',
#   u'title': u'Spirited Away',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNjczODkxNTAxN15BMl5BanBnXkFtZTcwMTcwNjUxMw@@._V1_.jpg',
#    u'width': 368},
#   u'num_votes': 864402,
#   u'rating': 8.6,
#   u'tconst': u'tt0120815',
#   u'title': u'Saving Private Ryan',
#   u'type': u'feature',
#   u'year': u'1998'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjMzNDUwNTIyMF5BMl5BanBnXkFtZTcwNjMwNDg3OA@@._V1_.jpg',
#    u'width': 391},
#   u'num_votes': 769652,
#   u'rating': 8.6,
#   u'tconst': u'tt0120586',
#   u'title': u'American History X',
#   u'type': u'feature',
#   u'year': u'1998'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIxNTU4MzY4MF5BMl5BanBnXkFtZTgwMzM4ODI3MjE@._V1_.jpg',
#    u'width': 1311},
#   u'num_votes': 898685,
#   u'rating': 8.6,
#   u'tconst': u'tt0816692',
#   u'title': u'Interstellar',
#   u'type': u'feature',
#   u'year': u'2014'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjQwNDYyNTk2N15BMl5BanBnXkFtZTgwMjQ0OTMyMjE@._V1_.jpg',
#    u'width': 334},
#   u'num_votes': 381612,
#   u'rating': 8.6,
#   u'tconst': u'tt0034583',
#   u'title': u'Casablanca',
#   u'type': u'feature',
#   u'year': u'1942'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgzMzM3NDY0NF5BMl5BanBnXkFtZTgwNDgwNDgwNzE@._V1_.jpg',
#    u'width': 978},
#   u'num_votes': 414251,
#   u'rating': 8.5,
#   u'tconst': u'tt0054215',
#   u'title': u'Psycho',
#   u'type': u'feature',
#   u'year': u'1960'},
#  {u'can_rate': True,
#   u'image': {u'height': 476,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA3NDQ5MDMzOV5BMl5BanBnXkFtZTgwODY2MjcyMjE@._V1_.jpg',
#    u'width': 320},
#   u'num_votes': 105738,
#   u'rating': 8.6,
#   u'tconst': u'tt0021749',
#   u'title': u'City Lights',
#   u'type': u'feature',
#   u'year': u'1931'},
#  {u'can_rate': True,
#   u'image': {u'height': 1536,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA0ODEzMTc1Nl5BMl5BanBnXkFtZTcwODM2MjAxNA@@._V1_.jpg',
#    u'width': 1021},
#   u'num_votes': 649891,
#   u'rating': 8.5,
#   u'tconst': u'tt0082971',
#   u'title': u'Raiders of the Lost Ark',
#   u'type': u'feature',
#   u'year': u'1981'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTYxNDA3MDQwNl5BMl5BanBnXkFtZTcwNTU4Mzc1Nw@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 490533,
#   u'rating': 8.6,
#   u'tconst': u'tt1675434',
#   u'title': u'The Intouchables',
#   u'type': u'feature',
#   u'year': u'2011'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjAxNDM0NTcyOV5BMl5BanBnXkFtZTgwODE1NjM0MTE@._V1_.jpg',
#    u'width': 332},
#   u'num_votes': 310446,
#   u'rating': 8.5,
#   u'tconst': u'tt0047396',
#   u'title': u'Rear Window',
#   u'type': u'feature',
#   u'year': u'1954'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjAyMTkxNjI5OF5BMl5BanBnXkFtZTYwMjI2MjA5._V1_.jpg',
#    u'width': 347},
#   u'num_votes': 139698,
#   u'rating': 8.6,
#   u'tconst': u'tt0027977',
#   u'title': u'Modern Times',
#   u'type': u'feature',
#   u'year': u'1936'},
#  {u'can_rate': True,
#   u'image': {u'height': 740,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_.jpg',
#    u'width': 500},
#   u'num_votes': 766176,
#   u'rating': 8.5,
#   u'tconst': u'tt0120689',
#   u'title': u'The Green Mile',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 473,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTI4MDAwMDY3N15BMl5BanBnXkFtZTcwODIwMzMzMQ@@._V1._CR46,1,342,473_.jpg',
#    u'width': 342},
#   u'num_votes': 732212,
#   u'rating': 8.5,
#   u'tconst': u'tt0103064',
#   u'title': u'Terminator 2: Judgment Day',
#   u'type': u'feature',
#   u'year': u'1991'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc4OTkyOTA3OF5BMl5BanBnXkFtZTYwMDIxNjk5._V1_.jpg',
#    u'width': 315},
#   u'num_votes': 488088,
#   u'rating': 8.5,
#   u'tconst': u'tt0253474',
#   u'title': u'The Pianist',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 665,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTI1MTY2OTIxNV5BMl5BanBnXkFtZTYwNjQ4NjY3._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 857319,
#   u'rating': 8.5,
#   u'tconst': u'tt0407887',
#   u'title': u'The Departed',
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 1893,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1218},
#   u'num_votes': 716803,
#   u'rating': 8.5,
#   u'tconst': u'tt0088763',
#   u'title': u'Back to the Future',
#   u'type': u'feature',
#   u'year': u'1985'},
#  {u'can_rate': True,
#   u'image': {u'height': 755,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU4OTQ3MDUyMV5BMl5BanBnXkFtZTgwOTA2MjU0MjE@._V1_.jpg',
#    u'width': 509},
#   u'num_votes': 381766,
#   u'rating': 8.5,
#   u'tconst': u'tt2582802',
#   u'title': u'Whiplash',
#   u'type': u'feature',
#   u'year': u'2014'},
#  {u'can_rate': True,
#   u'image': {u'height': 1377,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgwMzQzNTQ1Ml5BMl5BanBnXkFtZTgwMDY2NTYxMTE@._V1_.jpg',
#    u'width': 930},
#   u'num_votes': 965215,
#   u'rating': 8.5,
#   u'tconst': u'tt0172495',
#   u'title': u'Gladiator',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc4MjUxNDAwN15BMl5BanBnXkFtZTcwMDMwNDg3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 831169,
#   u'rating': 8.5,
#   u'tconst': u'tt0209144',
#   u'title': u'Memento',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTcyMzQ5NDM4OV5BMl5BanBnXkFtZTcwODUwNDg3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 443725,
#   u'rating': 8.5,
#   u'tconst': u'tt0078788',
#   u'title': u'Apocalypse Now',
#   u'type': u'feature',
#   u'year': u'1979'},
#  {u'can_rate': True,
#   u'image': {u'height': 667,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA4NDI0MTIxNF5BMl5BanBnXkFtZTYwNTM0MzY2._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 826535,
#   u'rating': 8.5,
#   u'tconst': u'tt0482571',
#   u'title': u'The Prestige',
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 1651,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjEyMzgwNTUzMl5BMl5BanBnXkFtZTcwNTMxMzM3Ng@@._V1_.jpg',
#    u'width': 1275},
#   u'num_votes': 629821,
#   u'rating': 8.5,
#   u'tconst': u'tt0110357',
#   u'title': u'The Lion King',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 1102,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU2ODM2NTkxNF5BMl5BanBnXkFtZTcwOTMwMzU3Mg@@._V1_.jpg',
#    u'width': 740},
#   u'num_votes': 337022,
#   u'rating': 8.5,
#   u'tconst': u'tt0057012',
#   u'title': u'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   u'type': u'feature',
#   u'year': u'1964'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc3NDYzODAwNV5BMl5BanBnXkFtZTgwODg1MTczMTE@._V1_.jpg',
#    u'width': 332},
#   u'num_votes': 137033,
#   u'rating': 8.5,
#   u'tconst': u'tt0043014',
#   u'title': u'Sunset Blvd.',
#   u'type': u'feature',
#   u'year': u'1950'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTU1ODQ4NjQyOV5BMl5BanBnXkFtZTgwOTQ3NDU2MTE@._V1_.jpg',
#    u'width': 1365},
#   u'num_votes': 553454,
#   u'rating': 8.5,
#   u'tconst': u'tt0078748',
#   u'title': u'Alien',
#   u'type': u'feature',
#   u'year': u'1979'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ5NDAwMDgzOV5BMl5BanBnXkFtZTgwNDI2MjA0MjE@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 134473,
#   u'rating': 8.5,
#   u'tconst': u'tt0032553',
#   u'title': u'The Great Dictator',
#   u'type': u'feature',
#   u'year': u'1940'},
#  {u'can_rate': True,
#   u'image': {u'height': 675,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDUzNjYwNDYyNl5BMl5BanBnXkFtZTcwNjU3ODQ0MQ@@._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 255025,
#   u'rating': 8.5,
#   u'tconst': u'tt0405094',
#   u'title': u'The Lives of Others',
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 499,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIzMTgzOTEwOF5BMl5BanBnXkFtZTgwNTUxNjcxMTE@._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 149141,
#   u'rating': 8.5,
#   u'tconst': u'tt0095765',
#   u'title': u'Cinema Paradiso',
#   u'type': u'feature',
#   u'year': u'1988'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIyNTQ5NjQ1OV5BMl5BanBnXkFtZTcwODg1MDU4OA@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 933695,
#   u'rating': 8.5,
#   u'tconst': u'tt1853728',
#   u'title': u'Django Unchained',
#   u'type': u'feature',
#   u'year': u'2012'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BODMxMjE3NTA4Ml5BMl5BanBnXkFtZTgwNDc0NTIxMDE@._V1_.jpg',
#    u'width': 1024},
#   u'num_votes': 598047,
#   u'rating': 8.4,
#   u'tconst': u'tt0081505',
#   u'title': u'The Shining',
#   u'type': u'feature',
#   u'year': u'1980'},
#  {u'can_rate': True,
#   u'image': {u'height': 497,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTUxNTcxMjI5NV5BMl5BanBnXkFtZTcwNTcyNjI3Mw@@._V1._CR17,1,331,497_.jpg',
#    u'width': 331},
#   u'num_votes': 118590,
#   u'rating': 8.5,
#   u'tconst': u'tt0050825',
#   u'title': u'Paths of Glory',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgyMzUwMTMxMl5BMl5BanBnXkFtZTgwODYyMDk2MjE@._V1_.jpg',
#    u'width': 342},
#   u'num_votes': 134555,
#   u'rating': 8.5,
#   u'tconst': u'tt0095327',
#   u'title': u'Grave of the Fireflies',
#   u'type': u'feature',
#   u'year': u'1988'},
#  {u'can_rate': True,
#   u'image': {u'height': 755,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTczOTA3MzY2N15BMl5BanBnXkFtZTcwOTYwNjE2MQ@@._V1_.jpg',
#    u'width': 510},
#   u'num_votes': 702565,
#   u'rating': 8.4,
#   u'tconst': u'tt0910970',
#   u'title': u'WALL\xb7E',
#   u'type': u'feature',
#   u'year': u'2008'},
#  {u'can_rate': True,
#   u'image': {u'height': 720,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_.jpg',
#    u'width': 486},
#   u'num_votes': 1123015,
#   u'rating': 8.5,
#   u'tconst': u'tt1345836',
#   u'title': u'The Dark Knight Rises',
#   u'type': u'feature',
#   u'year': u'2012'},
#  {u'can_rate': True,
#   u'image': {u'height': 1377,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjM4NTI5NzYyNV5BMl5BanBnXkFtZTgwNTkxNTYxMTE@._V1_.jpg',
#    u'width': 930},
#   u'num_votes': 809066,
#   u'rating': 8.4,
#   u'tconst': u'tt0169547',
#   u'title': u'American Beauty',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTYzNzU5MzQ4OV5BMl5BanBnXkFtZTcwMDcxNDg3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 480726,
#   u'rating': 8.4,
#   u'tconst': u'tt0090605',
#   u'title': u'Aliens',
#   u'type': u'feature',
#   u'year': u'1986'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjgzNTUwODQzN15BMl5BanBnXkFtZTcwMTc4ODE3OQ@@._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 216791,
#   u'rating': 8.4,
#   u'tconst': u'tt0119698',
#   u'title': u'Princess Mononoke',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 666,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTI3NTQyMzU5M15BMl5BanBnXkFtZTcwMTM2MjgyMQ@@._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 348841,
#   u'rating': 8.4,
#   u'tconst': u'tt0364569',
#   u'title': u'Oldboy',
#   u'type': u'feature',
#   u'year': u'2003'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ2Mjc1MDQwMl5BMl5BanBnXkFtZTcwNzUyOTUyMg@@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 293417,
#   u'rating': 8.4,
#   u'tconst': u'tt0033467',
#   u'title': u'Citizen Kane',
#   u'type': u'feature',
#   u'year': u'1941'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjQwMTQ0MzgwNl5BMl5BanBnXkFtZTgwNjc4ODE4MzE@._V1_.jpg',
#    u'width': 1309},
#   u'num_votes': 217013,
#   u'rating': 8.4,
#   u'tconst': u'tt0053125',
#   u'title': u'North by Northwest',
#   u'type': u'feature',
#   u'year': u'1959'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDMwMDcyODkzOV5BMl5BanBnXkFtZTcwNTQ1Njg3OA@@._V1_.jpg',
#    u'width': 353},
#   u'num_votes': 217052,
#   u'rating': 8.4,
#   u'tconst': u'tt0087843',
#   u'title': u'Once Upon a Time in America',
#   u'type': u'feature',
#   u'year': u'1984'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjE5Mzk5OTQ0Nl5BMl5BanBnXkFtZTYwNzUwMTQ5._V1_.jpg',
#    u'width': 297},
#   u'num_votes': 165630,
#   u'rating': 8.4,
#   u'tconst': u'tt0082096',
#   u'title': u'Das Boot',
#   u'type': u'feature',
#   u'year': u'1981'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNzY0NzQyNzQzOF5BMl5BanBnXkFtZTcwMTgwNTk4OQ@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 243883,
#   u'rating': 8.4,
#   u'tconst': u'tt0052357',
#   u'title': u'Vertigo',
#   u'type': u'feature',
#   u'year': u'1958'},
#  {u'can_rate': True,
#   u'image': {u'height': 1861,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ0MzI1NjYwOF5BMl5BanBnXkFtZTgwODU3NDU2MTE@._V1._CR93,97,1209,1861_.jpg',
#    u'width': 1209},
#   u'num_votes': 667633,
#   u'rating': 8.4,
#   u'tconst': u'tt0086190',
#   u'title': u'Star Wars: Episode VI - Return of the Jedi',
#   u'type': u'feature',
#   u'year': u'1983'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTc0MjgyNTUyNF5BMl5BanBnXkFtZTcwNDQzMDg0Nw@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 61428,
#   u'rating': 8.4,
#   u'tconst': u'tt0051201',
#   u'title': u'Witness for the Prosecution',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQyNjA5NzU5MV5BMl5BanBnXkFtZTgwMDk1MTA5MTE@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 97373,
#   u'rating': 8.4,
#   u'tconst': u'tt0022100',
#   u'title': u'M',
#   u'type': u'feature',
#   u'year': u'1931'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQxMTAwMDQ3Nl5BMl5BanBnXkFtZTcwODMwNTgzMQ@@._V1_.jpg',
#    u'width': 353},
#   u'num_votes': 651917,
#   u'rating': 8.4,
#   u'tconst': u'tt0105236',
#   u'title': u'Reservoir Dogs',
#   u'type': u'feature',
#   u'year': u'1992'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTYzNjkxMTczOF5BMl5BanBnXkFtZTgwODg5NDc2MjE@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 525054,
#   u'rating': 8.4,
#   u'tconst': u'tt0211915',
#   u'title': u'Am\xe9lie',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNjA4ODYxMDU3Nl5BMl5BanBnXkFtZTcwMzkzMTk3OA@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 724574,
#   u'rating': 8.4,
#   u'tconst': u'tt0112573',
#   u'title': u'Braveheart',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 433,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkzODMzODYwOF5BMl5BanBnXkFtZTcwODM2NjA2NQ@@._V1_.jpg',
#    u'width': 300},
#   u'num_votes': 563468,
#   u'rating': 8.4,
#   u'tconst': u'tt0180093',
#   u'title': u'Requiem for a Dream',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 1300,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY3MjM1Mzc4N15BMl5BanBnXkFtZTgwODM0NzAxMDE@._V1_.jpg',
#    u'width': 878},
#   u'num_votes': 547507,
#   u'rating': 8.4,
#   u'tconst': u'tt0066921',
#   u'title': u'A Clockwork Orange',
#   u'type': u'feature',
#   u'year': u'1971'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQ1Nzg3MDQwN15BMl5BanBnXkFtZTcwNDE2NDU2MQ@@._V1_.jpg',
#    u'width': 368},
#   u'num_votes': 496901,
#   u'rating': 8.3,
#   u'tconst': u'tt0075314',
#   u'title': u'Taxi Driver',
#   u'type': u'feature',
#   u'year': u'1976'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQzOTE4MTIzMV5BMl5BanBnXkFtZTgwODc1NDQ5MDE@._V1_.jpg',
#    u'width': 329},
#   u'num_votes': 95789,
#   u'rating': 8.4,
#   u'tconst': u'tt0036775',
#   u'title': u'Double Indemnity',
#   u'type': u'feature',
#   u'year': u'1944'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgxOTY4Mjc0MF5BMl5BanBnXkFtZTcwNTA4MDQyMw@@._V1_.jpg',
#    u'width': 1448},
#   u'num_votes': 532674,
#   u'rating': 8.3,
#   u'tconst': u'tt0435761',
#   u'title': u'Toy Story 3',
#   u'type': u'feature',
#   u'year': u'2010'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA4MzI1NDY2Nl5BMl5BanBnXkFtZTcwMTcyODc5Mw@@._V1_.jpg',
#    u'width': 328},
#   u'num_votes': 210825,
#   u'rating': 8.4,
#   u'tconst': u'tt0056592',
#   u'title': u'To Kill a Mockingbird',
#   u'type': u'feature',
#   u'year': u'1962'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMzAwMjM4NzA2OV5BMl5BanBnXkFtZTcwMDI0NzAwMQ@@._V1_.jpg',
#    u'width': 324},
#   u'num_votes': 189329,
#   u'rating': 8.4,
#   u'tconst': u'tt0056172',
#   u'title': u'Lawrence of Arabia',
#   u'type': u'feature',
#   u'year': u'1962'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY4NzcwODg3Nl5BMl5BanBnXkFtZTcwNTEwOTMyMw@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 654083,
#   u'rating': 8.3,
#   u'tconst': u'tt0338013',
#   u'title': u'Eternal Sunshine of the Spotless Mind',
#   u'type': u'feature',
#   u'year': u'2004'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjA4NzY4ODk4Nl5BMl5BanBnXkFtZTgwOTcxNTYxMTE@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 475679,
#   u'rating': 8.3,
#   u'tconst': u'tt0093058',
#   u'title': u'Full Metal Jacket',
#   u'type': u'feature',
#   u'year': u'1987'},
#  {u'can_rate': True,
#   u'image': {u'height': 704,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTg5NDkwMTk5N15BMl5BanBnXkFtZTYwODg3MDk2._V1_.jpg',
#    u'width': 475},
#   u'num_votes': 266047,
#   u'rating': 8.3,
#   u'tconst': u'tt0086879',
#   u'title': u'Amadeus',
#   u'type': u'feature',
#   u'year': u'1984'},
#  {u'can_rate': True,
#   u'image': {u'height': 1388,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTY5MjM1OTAyOV5BMl5BanBnXkFtZTgwMDkwODg4MDE@._V1._CR52,57,915,1388_.jpg',
#    u'width': 915},
#   u'num_votes': 172432,
#   u'rating': 8.3,
#   u'tconst': u'tt0070735',
#   u'title': u'The Sting',
#   u'type': u'feature',
#   u'year': u'1973'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BNDYyMDgxNDQ5Nl5BMl5BanBnXkFtZTcwMjc1ODg3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 419033,
#   u'rating': 8.3,
#   u'tconst': u'tt0062622',
#   u'title': u'2001: A Space Odyssey',
#   u'type': u'feature',
#   u'year': u'1968'},
#  {u'can_rate': True,
#   u'image': {u'height': 3300,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIzMzAyMzg1Nl5BMl5BanBnXkFtZTgwMzMyNzk0MTE@._V1_.jpg',
#    u'width': 2285},
#   u'num_votes': 92461,
#   u'rating': 8.3,
#   u'tconst': u'tt0040522',
#   u'title': u'Bicycle Thieves',
#   u'type': u'feature',
#   u'year': u'1948'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTUxMTIyNTI4Nl5BMl5BanBnXkFtZTcwNTk1ODQyMg@@._V1_.jpg',
#    u'width': 324},
#   u'num_votes': 147358,
#   u'rating': 8.3,
#   u'tconst': u'tt0045152',
#   u'title': u"Singin' in the Rain",
#   u'type': u'feature',
#   u'year': u'1952'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTk5NzE0MDQyNl5BMl5BanBnXkFtZTcwNzk4Mjk3OA@@._V1_.jpg',
#    u'width': 344},
#   u'num_votes': 591508,
#   u'rating': 8.3,
#   u'tconst': u'tt0208092',
#   u'title': u'Snatch.',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTgwMjI4MzU5N15BMl5BanBnXkFtZTcwMTMyNTk3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 609471,
#   u'rating': 8.3,
#   u'tconst': u'tt0114709',
#   u'title': u'Toy Story',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkzODczMTgwM15BMl5BanBnXkFtZTYwNTAwODI5._V1_.jpg',
#    u'width': 271},
#   u'num_votes': 376215,
#   u'rating': 8.3,
#   u'tconst': u'tt0071853',
#   u'title': u'Monty Python and the Holy Grail',
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 1441,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjIzMDI4MTUzOV5BMl5BanBnXkFtZTcwNDY3NjA3Mg@@._V1_.jpg',
#    u'width': 974},
#   u'num_votes': 866353,
#   u'rating': 8.3,
#   u'tconst': u'tt0361748',
#   u'title': u'Inglourious Basterds',
#   u'type': u'feature',
#   u'year': u'2009'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTkzNTgxMDU1OF5BMl5BanBnXkFtZTgwOTQ3MjI2MzE@._V1_.jpg',
#    u'width': 358},
#   u'num_votes': 65377,
#   u'rating': 8.4,
#   u'tconst': u'tt0012349',
#   u'title': u'The Kid',
#   u'type': u'feature',
#   u'year': u'1921'},
#  {u'can_rate': True,
#   u'image': {u'height': 488,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjMzOTc2MDI3N15BMl5BanBnXkFtZTgwNTE4Njc3NjE@._V1_.jpg',
#    u'width': 329},
#   u'num_votes': 408138,
#   u'rating': 8.3,
#   u'tconst': u'tt0119488',
#   u'title': u'L.A. Confidential',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTQzMjIzOTEzMF5BMl5BanBnXkFtZTcwMTUzNTk3NA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 153815,
#   u'rating': 8.3,
#   u'tconst': u'tt0059578',
#   u'title': u'For a Few Dollars More',
#   u'type': u'feature',
#   u'year': u'1965'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMTM1OTc4MzgzNl5BMl5BanBnXkFtZTcwNTE2NjgyMw@@._V1_.jpg',
#    u'width': 1234},
#   u'num_votes': 107267,
#   u'rating': 8.3,
#   u'tconst': u'tt0053604',
#   u'title': u'The Apartment',
#   u'type': u'feature',
#   u'year': u'1960'},
#  {u'can_rate': True,
#   u'image': {u'height': 683,
#    u'url': u'http://ia.media-imdb.com/images/M/MV5BMjEzMzA4NDE2OF5BMl5BanBnXkFtZTcwNTc5MDI2NQ@@._V1._CR0,0,503,683_.jpg',
#    u'width': 503},
#   u'num_votes': 100627,
#   u'rating': 8.3,
#   u'tconst': u'tt0042876',
#   u'title': u'Rashomon',
#   u'type': u'feature',
#   u'year': u'1950'}]
