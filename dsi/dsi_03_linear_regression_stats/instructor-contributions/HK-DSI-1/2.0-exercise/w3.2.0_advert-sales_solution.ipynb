# %% [markdown]
# # Advertising and Sales
# We are interested to find out whether there are linear relationships between advertising dollars spent and the sales of a product

# %%
import pandas as pd

# read data into a DataFrame
data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# What are the features?
# * TV: advertising dollars spent on TV for a single product in a given market (in thousands of dollars)
# * Radio: advertising dollars spent on Radio
# * Newspaper: advertising dollars spent on Newspaper
#
# What is the response?
# * Sales: sales of a single product in a given market (in thousands of widgets)

# %%
data.shape
# Out:
# (200, 4)

# %%
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, sharey=True)
data.plot(kind='scatter', x='TV', y='Sales', ax=axs[0], figsize=(16, 8))
data.plot(kind='scatter', x='Radio', y='Sales', ax=axs[1])
data.plot(kind='scatter', x='Newspaper', y='Sales', ax=axs[2])

# %%
from sklearn import linear_model
lm = linear_model.LinearRegression(fit_intercept = True)
from sklearn.metrics import mean_squared_error

X = data[['TV']]
y = data.Sales

from sklearn.linear_model import LinearRegression
model = lm.fit(X, y)
y_pred = model.predict(X)


print "Coefficients", zip(['TV'], model.coef_)
print "Intercept",model.intercept_

plt.scatter(X, y)#, s=30, c='b', zorder=10)
plt.xlabel("TV")
plt.ylabel("Actual Sales")
plt.plot(X, y_pred, color='red')

print "MSE:", mean_squared_error(y, y_pred)
# Out:
# Coefficients [('TV', 0.047536640433019764)]
# Intercept 7.03259354913
# MSE: 10.5126529157

# %%
X = data[['Radio']]
y = data.Sales


from sklearn.linear_model import LinearRegression
model = lm.fit(X, y)
y_pred = model.predict(X)


print "Coefficients", zip(['Radio'], model.coef_)
print "Intercept",model.intercept_

plt.scatter(X, y)#, s=30, c='b', zorder=10)
plt.xlabel("Radio")
plt.ylabel("Actual Sales")
plt.plot(X, y_pred, color='red')

print "MSE:", mean_squared_error(y, y_pred)
# Out:
# Coefficients [('Radio', 0.20249578339243965)]
# Intercept 9.31163809516
# MSE: 18.0923977451

# %%
X = data[['Newspaper']]
y = data.Sales


from sklearn.linear_model import LinearRegression
model = lm.fit(X, y)
y_pred = model.predict(X)


print "Coefficients", zip(['Newspaper'], model.coef_)
print "Intercept",model.intercept_

plt.scatter(X, y)#, s=30, c='b', zorder=10)
plt.xlabel("Newspaper")
plt.ylabel("Actual Sales")
plt.plot(X, y_pred, color='red')

print "MSE:", mean_squared_error(y, y_pred)
# Out:
# Coefficients [('Newspaper', 0.054693098472273362)]
# Intercept 12.3514070693
# MSE: 25.6740227206

# %%
X = data[['TV', 'Radio', 'Newspaper']]
y = data.Sales


from sklearn.linear_model import LinearRegression
model = lm.fit(X, y)
y_pred = model.predict(X)


print "Coefficients", zip(['TV', 'Radio', 'Newspaper'], model.coef_)
print "Intercept",model.intercept_

plt.scatter(y_pred, y)#, s=30, c='b', zorder=10)
plt.xlabel("Predicted Sales")
plt.ylabel("Actual Sales")


print "MSE:", mean_squared_error(y, y_pred)
# Out:
# Coefficients [('TV', 0.045764645455397608), ('Radio', 0.18853001691820462), ('Newspaper', -0.0010374930424762972)]
# Intercept 2.93888936946
# MSE: 2.78412631451
